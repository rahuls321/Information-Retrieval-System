# %%
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import warnings
import math

# %% [markdown]
# ## Loading preprocessed document wise vocab

# %%
vocab_doc_wise_tokenization = np.load('vocab_doc_wise_tokenization.npy', allow_pickle='TRUE').item()
vocab_doc_wise_stemming = np.load('vocab_doc_wise_stemming.npy', allow_pickle='TRUE').item()
print(vocab_doc_wise_tokenization)
print(vocab_doc_wise_stemming)
# Out:
# {'P_386': ['vrihadaswa', 'said', 'after', 'long', 'time', 'had', 'passed', 'away', 'brahmana', 'named', 'parnada', 'returned', 'to', 'the', 'city', 'of', 'the', 'vidarbhas', 'and', 'said', 'unto', 'the', 'daughter', 'of', 'bhima', 'damayanti', 'seeking', 'nala', 'the', 'king', 'of', 'nishadhas', 'came', 'to', 'the', 'city', 'of', 'ayodhya', 'and', 'appeared', 'before', 'the', 'son', 'of', 'bhangasura', 'and', 'best', 'of', 'women', 'repeated', 'those', 'words', 'of', 'thine', 'in', 'the', 'presence', 'of', 'the', 'blessed', 'rituparna', 'but', 'hearing', 'them', 'neither', 'that', 'ruler', 'of', 'men', 'nor', 'his', 'courtiers', 'answered', 'anything', 'although', 'uttered', 'them', 'repeatedly', 'then', 'after', 'had', 'been', 'dismissed', 'by', 'the', 'monarch', 'was', 'accosted', 'by', 'person', 'in', 'the', 'service', 'of', 'rituparna', 'named', 'vahuka', 'and', 'vahuka', 'is', 'the', 'charioteer', 'of', 'that', 'king', 'of', 'unsightly', 'appearance', 'and', 'possessed', 'of', 'short', 'arms', 'and', 'he', 'is', 'skillful', 'in', 'driving', 'with', 'speed', 'and', 'well', 'acquainted', 'with', 'the', 'culinary', 'art', 'and', 'sighing', 'frequently', 'and', 'weeping', 'again', 'and', 'again', 'he', 'inquired', 'about', 'my', 'welfare', 'and', 'afterwards', 'said', 'these', 'words', 'chaste', 'women', 'although', 'fallen', 'into', 'distress', 'yet', 'protect', 'themselves', 'and', 'thus', 'certainly', 'secure', 'heaven', 'although', 'they', 'may', 'be', 'deserted', 'by', 'their', 'lords', 'they', 'do', 'not', 'yet', 'become', 'angry', 'on', 'that', 'account', 'for', 'women', 'that', 'are', 'chaste', 'lead', 'their', 'lives', 'encased', 'in', 'the', 'armour', 'of', 'virtuous', 'behaviour', 'it', 'behoveth', 'her', 'not', 'to', 'be', 'angry', 'since', 'he', 'that', 'deserted', 'her', 'was', 'overwhelmed', 'with', 'calamity', 'and', 'deprived', 'of', 'every', 'bliss', 'beauteous', 'and', 'virtuous', 'woman', 'should', 'not', 'be', 'angry', 'with', 'one', 'that', 'was', 'deprived', 'by', 'birds', 'of', 'his', 'garment', 'while', 'striving', 'to', 'procure', 'sustenance', 'and', 'who', 'is', 'being', 'consumed', 'with', 'grief', 'whether', 'treated', 'well', 'or', 'ill', 'such', 'wife', 'should', 'never', 'indulge', 'in', 'ire', 'beholding', 'her', 'husband', 'in', 'that', 'plight', 'despoiled', 'of', 'kingdom', 'and', 'destitute', 'of', 'prosperity', 'oppressed', 'with', 'hunger', 'and', 'overwhelmed', 'with', 'calamity', 'hearing', 'these', 'words', 'of', 'his', 'have', 'speedily', 'come', 'here', 'thou', 'hast', 'now', 'heard', 'all', 'do', 'what', 'thou', 'thinkest', 'proper', 'and', 'inform', 'the', 'king', 'of', 'it', 'king', 'having', 'heard', 'these', 'words', 'of', 'parnada', 'damayanti', 'with', 'tearful', 'eyes', 'came', 'to', 'her', 'mother', 'and', 'spake', 'unto', 'her', 'in', 'private', 'mother', 'king', 'bhima', 'should', 'not', 'by', 'any', 'means', 'be', 'made', 'acquainted', 'with', 'my', 'purpose', 'in', 'thy', 'presence', 'will', 'employ', 'that', 'best', 'of', 'brahmanas', 'sudeva', 'if', 'thou', 'desirest', 'my', 'welfare', 'act', 'in', 'such', 'way', 'that', 'king', 'bhima', 'may', 'not', 'know', 'my', 'purpose', 'let', 'sudeva', 'without', 'delay', 'go', 'hence', 'to', 'the', 'city', 'of', 'ayodhya', 'for', 'the', 'purpose', 'of', 'bringing', 'nala', 'mother', 'having', 'performed', 'the', 'same', 'auspicious', 'rites', 'by', 'virtue', 'of', 'which', 'he', 'had', 'speedily', 'brought', 'me', 'into', 'the', 'midst', 'of', 'friends', 'with', 'these', 'words', 'after', 'parnada', 'had', 'recovered', 'from', 'fatigue', 'the', 'princess', 'of', 'vidarbha', 'worshipped', 'him', 'with', 'profuse', 'wealth', 'and', 'also', 'said', 'when', 'nala', 'will', 'come', 'here', 'brahmana', 'will', 'bestow', 'on', 'thee', 'wealth', 'in', 'abundance', 'again', 'thou', 'hast', 'done', 'me', 'the', 'immense', 'service', 'which', 'none', 'else', 'indeed', 'can', 'do', 'me', 'for', 'owing', 'to', 'that', 'service', 'of', 'th ...
# {'P_386': ['vrihadaswa', 'said', 'after', 'long', 'time', 'had', 'pass', 'away', 'brahmana', 'name', 'parnada', 'return', 'to', 'the', 'citi', 'of', 'the', 'vidarbha', 'and', 'said', 'unto', 'the', 'daughter', 'of', 'bhima', 'damayanti', 'seek', 'nala', 'the', 'king', 'of', 'nishadha', 'came', 'to', 'the', 'citi', 'of', 'ayodhya', 'and', 'appear', 'befor', 'the', 'son', 'of', 'bhangasura', 'and', 'best', 'of', 'women', 'repeat', 'those', 'word', 'of', 'thine', 'in', 'the', 'presenc', 'of', 'the', 'bless', 'rituparna', 'but', 'hear', 'them', 'neither', 'that', 'ruler', 'of', 'men', 'nor', 'his', 'courtier', 'answer', 'anyth', 'although', 'utter', 'them', 'repeat', 'then', 'after', 'had', 'been', 'dismiss', 'by', 'the', 'monarch', 'was', 'accost', 'by', 'person', 'in', 'the', 'servic', 'of', 'rituparna', 'name', 'vahuka', 'and', 'vahuka', 'is', 'the', 'chariot', 'of', 'that', 'king', 'of', 'unsight', 'appear', 'and', 'possess', 'of', 'short', 'arm', 'and', 'he', 'is', 'skill', 'in', 'drive', 'with', 'speed', 'and', 'well', 'acquaint', 'with', 'the', 'culinari', 'art', 'and', 'sigh', 'frequent', 'and', 'weep', 'again', 'and', 'again', 'he', 'inquir', 'about', 'my', 'welfar', 'and', 'afterward', 'said', 'these', 'word', 'chast', 'women', 'although', 'fallen', 'into', 'distress', 'yet', 'protect', 'themselv', 'and', 'thus', 'certain', 'secur', 'heaven', 'although', 'they', 'may', 'be', 'desert', 'by', 'their', 'lord', 'they', 'do', 'not', 'yet', 'becom', 'angri', 'on', 'that', 'account', 'for', 'women', 'that', 'are', 'chast', 'lead', 'their', 'live', 'encas', 'in', 'the', 'armour', 'of', 'virtuous', 'behaviour', 'it', 'behoveth', 'her', 'not', 'to', 'be', 'angri', 'sinc', 'he', 'that', 'desert', 'her', 'was', 'overwhelm', 'with', 'calam', 'and', 'depriv', 'of', 'everi', 'bliss', 'beauteous', 'and', 'virtuous', 'woman', 'should', 'not', 'be', 'angri', 'with', 'one', 'that', 'was', 'depriv', 'by', 'bird', 'of', 'his', 'garment', 'while', 'strive', 'to', 'procur', 'susten', 'and', 'who', 'is', 'be', 'consum', 'with', 'grief', 'whether', 'treat', 'well', 'or', 'ill', 'such', 'wife', 'should', 'never', 'indulg', 'in', 'ire', 'behold', 'her', 'husband', 'in', 'that', 'plight', 'despoil', 'of', 'kingdom', 'and', 'destitut', 'of', 'prosper', 'oppress', 'with', 'hunger', 'and', 'overwhelm', 'with', 'calam', 'hear', 'these', 'word', 'of', 'his', 'have', 'speedili', 'come', 'here', 'thou', 'hast', 'now', 'heard', 'all', 'do', 'what', 'thou', 'thinkest', 'proper', 'and', 'inform', 'the', 'king', 'of', 'it', 'king', 'have', 'heard', 'these', 'word', 'of', 'parnada', 'damayanti', 'with', 'tear', 'eye', 'came', 'to', 'her', 'mother', 'and', 'spake', 'unto', 'her', 'in', 'privat', 'mother', 'king', 'bhima', 'should', 'not', 'by', 'ani', 'mean', 'be', 'made', 'acquaint', 'with', 'my', 'purpos', 'in', 'thi', 'presenc', 'will', 'employ', 'that', 'best', 'of', 'brahmana', 'sudeva', 'if', 'thou', 'desirest', 'my', 'welfar', 'act', 'in', 'such', 'way', 'that', 'king', 'bhima', 'may', 'not', 'know', 'my', 'purpos', 'let', 'sudeva', 'without', 'delay', 'go', 'henc', 'to', 'the', 'citi', 'of', 'ayodhya', 'for', 'the', 'purpos', 'of', 'bring', 'nala', 'mother', 'have', 'perform', 'the', 'same', 'auspici', 'rite', 'by', 'virtu', 'of', 'which', 'he', 'had', 'speedili', 'brought', 'me', 'into', 'the', 'midst', 'of', 'friend', 'with', 'these', 'word', 'after', 'parnada', 'had', 'recov', 'from', 'fatigu', 'the', 'princess', 'of', 'vidarbha', 'worship', 'him', 'with', 'profus', 'wealth', 'and', 'also', 'said', 'when', 'nala', 'will', 'come', 'here', 'brahmana', 'will', 'bestow', 'on', 'thee', 'wealth', 'in', 'abund', 'again', 'thou', 'hast', 'done', 'me', 'the', 'immens', 'servic', 'which', 'none', 'els', 'inde', 'can', 'do', 'me', 'for', 'owe', 'to', 'that', 'servic', 'of', 'thine', 'thou', 'best', 'of', 'the', 'regener', 'one', 'shall', 'speedili', 'regain', 'my', 'lost', 'lord', 'and', 'thus', 'address', 'by', 'damayanti', 'that', 'high', 'mind', 'brahmana',  ...

# %% [markdown]
# ## Boolean Retrieval System

# %%
#Creating Node which has three sub-nodes containing document ID, freq of word in that docID 
#and next to link with next docID
class Node:
    def __init__(self, docID, freq=None):
        self.docID = docID
        self.freq = freq
        self.next = None

# %%
#Creating word freq for each doc
def get_word_freq(vocab):
    word_freq={}
    for word in vocab:
        if word in word_freq.keys():
            word_freq[word]+=1
        else: word_freq[word]=1
    return word_freq

# %% [markdown]
# ### Creating Postings list

# %%
postings_list = {}
doc_index = {}
ind=0
for doc_id, vocab in vocab_doc_wise_stemming.items():
    word_freq = get_word_freq(vocab)
    for word, freq in word_freq.items():
        if word in postings_list.keys():
            firstNode = postings_list[word]
            while firstNode.next is not None:
                firstNode = firstNode.next
            firstNode.next = Node(ind, freq)
        else:
            postings_list[word] = Node(ind, freq)
    doc_index[ind] = doc_id
    ind+=1

# %%
for word, node in postings_list.items():
    print(word, end='->')
    while node is not None:
        print(node.docID, end='->')
        print(node.freq, end=' ')
        node=node.next
    print('\n')
# Out:
# vrihadaswa->0->1
#
# said->0->5 1->1 4->2
#
# after->0->5 1->9 2->18 3->9 4->2
#
# long->0->1 1->6 2->1 3->4
#
# time->0->2 1->5 2->21 3->12
#
# had->0->6 1->8 2->8 3->11 4->1
#
# pass->0->1 2->1 3->1
#
# away->0->2 1->1 4->1
#
# brahmana->0->4
#
# name->0->2 1->9 2->1 3->5 4->2
#
# parnada->0->3
#
# return->0->1 1->1 2->3 3->2
#
# to->0->10 1->58 2->262 3->48 4->31
#
# the->0->28 1->333 2->538 3->151 4->136
#
# citi->0->4 1->1 2->1 3->6 4->5
#
# of->0->33 1->150 2->421 3->96 4->60
#
# vidarbha->0->2
#
# and->0->28 1->71 2->334 3->83 4->20
#
# unto->0->3
#
# daughter->0->2 4->1
#
# bhima->0->4
#
# damayanti->0->5
#
# seek->0->1 3->1
#
# nala->0->4
#
# king->0->8 1->8 4->1
#
# nishadha->0->1
#
# came->0->2 1->2
#
# ayodhya->0->3
#
# appear->0->2 1->2 2->6 3->1
#
# befor->0->1 1->2 2->6 3->1 4->2
#
# son->0->1 1->6 2->1 3->1
#
# bhangasura->0->1
#
# best->0->3 3->24
#
# women->0->3 2->22 4->1
#
# repeat->0->2 1->4 2->5 3->4 4->4
#
# those->0->1 1->1 2->8 3->3
#
# word->0->7 1->8 2->4 3->4 4->4
#
# thine->0->2
#
# in->0->11 1->89 2->305 3->51 4->34
#
# presenc->0->3 2->3
#
# bless->0->1
#
# rituparna->0->4
#
# but->0->1 1->8 2->12 3->6 4->3
#
# hear->0->2 2->4 3->3
#
# them->0->2 1->2 2->2 3->1
#
# neither->0->1
#
# that->0->13 1->10 2->60 3->7 4->5
#
# ruler->0->1 1->10
#
# men->0->1 2->4 3->1
#
# nor->0->1
#
# his->0->4 1->17 2->3 3->47
#
# courtier->0->1
#
# answer->0->1
#
# anyth->0->1
#
# although->0->3 1->1 2->11 3->3
#
# utter->0->2
#
# then->0->2 1->2 2->3 3->4
#
# been->0->3 1->7 2->35 3->3 4->2
#
# dismiss->0->1
#
# by->0->8 1->35 2->70 3->21 4->8
#
# monarch->0->2
#
# was->0->3 1->41 2->30 3->42 4->13
#
# accost->0->1
#
# person->0->1 2->10
#
# servic->0->3 3->3
#
# vahuka->0->2
#
# is->0->4 1->38 2->89 3->3 4->37
#
# chariot->0->1
#
# unsight->0->1
#
# possess->0->1 1->1
#
# short->0->1 1->2 2->2 3->1
#
# arm->0->1 1->1 3->3 4->1
#
# he->0->7 1->11 2->1 3->33
#
# skill->0->1 2->1
#
# drive->0->1
#
# with->0->12 1->21 2->106 3->23 4->10
#
# speed->0->1 2->1
#
# well->0->2 1->2 2->3 4->5
#
# acquaint->0->2
#
# culinari->0->1
#
# art->0->1 4->2
#
# sigh->0->1
#
# frequent->0->1 1->1 2->2 4->1
#
# weep->0->1
#
# again->0->3 3->4
#
# inquir->0->1
#
# about->0->1 1->3 2->9 3->8 4->3
#
# my->0->5 3->2
#
# welfar->0->2
#
# afterward->0->1 1->1 2->1
#
# these->0->5 1->2 2->18
#
# chast->0->2
#
# fallen->0->1
#
# into->0->2 1->5 2->7 3->3 4->1
#
# distress->0->2
#
# yet->0->2 2->2
#
# protect->0->1 2->1
#
# themselv->0->1 1->1
#
# thus->0->3 2->4
#
# certain->0->1 2->8
#
# secur->0->1 1->1 3->1
#
# heaven->0->1
#
# they->0->2 1->5 2->8 3->1
#
# may->0->2 1->2 2->53 3->12
#
# be->0->5 1->1 2->59 3->6 4->3
#
# desert->0->2
#
# their->0->2 1->1 2->16 3->2
#
# lord->0->2
#
# do->0->3 1->2 2->9 3->2 4->1
#
# not->0->7 1->5 2->42 3->4
#
# becom->0->1 1->1 2->5 3->2
#
# angri->0->3
#
# on->0->2 1->25 2->75 3->17 4->10
#
# account->0->1 3->1
#
# for->0->4 1->17 2->114 3->63 4->7
#
# are->0->2 1->16 2->73 3->2 4->9
#
# lead->0->1 1->1 2->9 3->1 4->2
#
# live->0->2 2->4 3->3
#
# encas->0->1
#
# armour->0->1
#
# virtuous->0->2
#
# behaviour->0->1 2->10
#
# it->0->3 1->26 2->44 3->13 4->19
#
# behoveth->0->1
#
# her->0->8 2->2 3->3
#
# sinc->0->1 1->1 2->3
#
# overwhelm->0->2
#
# calam->0->2
#
# depriv->0->2
#
# everi->0->1
#
# bliss->0->1
#
# beauteous->0->1
#
# woman->0->1 2->9
#
# should->0->3 2->1
#
# one->0->2 1->4 2->12 3->6 4->1
#
# bird->0->2 2->5 3->2
#
# garment->0->1
#
# while->0->1 1->2 2->14 3->3 4->1
#
# strive->0->1
#
# procur->0->1
#
# susten->0->1
#
# who->0->1 1->4 2->10 3->3 4->4
#
# consum->0->1 2->2
#
# grief->0->2
#
# whether->0->2 2->6 3->1
#
# treat->0->1 2->9
#
# or->0->2 1->8 2->75 3->1 4->3
#
# ill->0->1 2->2
#
# such->0->2 1->2 2->12 3->1 4->1
#
# wife->0->1 1->2 3->1
#
# never->0->1 3->1
#
# indulg->0->1
#
# ire->0->1
#
# behold->0->1
#
# husband->0->2 3->2
#
# plight->0->1
#
# despoil->0->1
#
# kingdom->0->1 1->1 2->1
#
# destitut->0->1
#
# prosper->0->1
#
# oppress->0->2
#
# hunger->0->1
#
# have->0->4 1->6 2->43 3->4 4->2
#
# speedili->0->3
#
# come->0->2 1->1 2->1 3->3
#
# here->0->2 1->2
#
# thou->0->6
#
# hast->0->2 1->1
#
# now->0->1 1->9 2->1 3->1 4->4
#
# heard->0->2
#
# all->0->3 1->3 2->6 3->4
#
# what->0->1 1->2 2->3
#
# thinkest->0->1
#
# proper->0->1 2->1
#
# inform->0->1 1->1 2->1 4->1
#
# tear->0->1
#
# eye->0->1 2->4
#
# mother->0->4 2->7 3->3
#
# spake->0->1
#
# privat->0->1
#
# ani->0->1 1->1 2->4 3->1 4->1
#
# mean->0->1 1->2 2->3 4->3
#
# made->0->1 1->1 2->2 3->2 4->2
#
# purpos->0->3 2->1
#
# thi->0->1
#
# will->0->6 2->4 3->4
#
# employ->0->1 2->1
#
# sudeva->0->5
#
# if->0->2 2->11
#
# desirest->0->1
#
# act->0->1 2->1 3->2
#
# way->0->1 1->1 2->3 3->7
#
# know->0->2 2->2
#
# let->0->1
#
# without->0->2 2->2 3->1
#
# delay->0->2
#
# go->0->4
#
# henc->0->1 1->1
#
# bring->0->1
#
# perform->0->1 2->3 3->1
#
# same->0->1 2->2 3->1
#
# auspici->0->2 4->2
#
# rite->0->1
#
# virtu->0->1
#
# which->0->2 1->7 2->17 3->9 4->13
#
# brought->0->1 3->1
#
# me->0->3 2->4
#
# midst->0->1
#
# friend->0->1
#
# recov->0->1
#
# from->0->1 1->16 2->91 3->12 4->7
#
# fatigu->0->1 2->1
#
# princess->0->1 1->1
#
# worship->0->1 4->1
#
# him->0->2 1->5 2->1 3->7
#
# profus->0->1
#
# wealth->0->2
#
# also->0->1 1->5 2->32 3->4 4->6
#
# when->0->1 1->6 2->13 3->4 4->1
#
# bestow->0->1 1->1
#
# thee->0->2
#
# abund->0->1 2->1
#
# done->0->1
#
# immens->0->1
#
# none->0->1 1->9 2->10 3->11 4->9
#
# els->0->1
#
# inde->0->1
#
# can->0->1 1->1 2->42 3->8 4->1
#
# owe->0->1
#
# regener->0->1
#
# shall->0->1
#
# regain->0->1
#
# lost->0->1 1->6
#
# address->0->3
#
# high->0->1 1->5 2->14 3->1
#
# mind->0->1
#
# comfort->0->1
#
# benedictori->0->1
#
# import->0->1 1->2 2->5 3->8 4->3
#
# went->0->1 3->1
#
# home->0->1 3->6 4->2
#
# regard->0->1 2->5
#
# mission->0->1
#
# success->0->1 1->1 2->1 3->5
#
# gone->0->1
#
# call->0->1 1->1 2->2 3->2 4->3
#
# yudhishthira->0->1
#
# say->0->2 2->1 3->1
#
# straight->0->1
#
# as->0->2 1->28 2->61 3->9 4->12
#
# tell->0->1
#
# there->0->1 1->9 2->7 3->1 4->7
#
# hold->0->1 1->1
#
# anoth->0->1 1->2 2->3
#
# swayamvara->0->1
#
# princ->0->1 1->2 2->1 3->13
#
# thither->0->2
#
# calcul->0->1
#
# find->0->1 1->1 2->3
#
# ceremoni->0->1 1->1 4->2
#
# take->0->1 2->5 4->1
#
# place->0->1 1->6 2->2 4->2
#
# tomorrow->0->2 3->1
#
# repress->0->1 2->1
#
# foe->0->1
#
# possibl->0->1 2->7
#
# sun->0->1 1->1 2->2
#
# hath->0->1
#
# risen->0->1
#
# she->0->2 1->1 2->1 3->1
#
# choos->0->1
#
# second->0->1 1->3 2->6
#
# doth->0->1
#
# heroic->0->1
#
# liveth->0->1
#
# set->0->1 2->2 3->1 4->1
#
# out->0->1 1->2 2->2 3->1 4->2
#
# direct->0->1 2->7 3->21
#
# mw->1->107 2->93 3->130 4->103
#
# parser->1->108 2->94 3->129 4->104
#
# output->1->108 2->94 3->129 4->104
#
# infobox->1->10 2->10 3->10 4->10
#
# subbox->1->1 2->1 3->1 4->1
#
# pad->1->11 2->7 3->26 4->10
#
# border->1->9 2->9 3->16 4->9
#
# margin->1->17 2->15 3->27 4->15
#
# px->1->9 2->6 3->13 4->9
#
# width->1->8 2->7 3->13 4->9
#
# auto->1->3 2->3 3->3 4->3
#
# min->1->1 2->2 3->1 4->1
#
# font->1->17 2->14 3->26 4->15
#
# size->1->14 2->12 3->19 4->12
#
# clear->1->3 2->2 3->9 4->2
#
# float->1->5 2->3 3->9 4->5
#
# background->1->13 2->13 3->15 4->13
#
# color->1->13 2->13 3->13 4->13
#
# transpar->1->10 2->10 3->10 4->10
#
# col->1->1 2->1 3->9 4->1
#
# child->1->1 2->6 3->4 4->1
#
# navbar->1->15 2->15 3->16 4->15
#
# bodi->1->7 2->11 3->9 4->8
#
# minerva->1->7 2->7 3->8 4->7
#
# header->1->1 2->1 3->1 4->1
#
# subhead->1->1 2->1 3->1 4->1
#
# abov->1->2 2->4 3->3 4->1
#
# titl->1->7 2->6 3->14 4->5
#
# imag->1->5 2->8 3->5 4->3
#
# full->1->2 2->3 3->3 4->2
#
# data->1->5 2->5 3->2 4->1
#
# below->1->1 2->2 3->3 4->1
#
# text->1->12 2->10 3->15 4->12
#
# align->1->10 2->7 3->14 4->10
#
# center->1->4 2->8 3->6 4->4
#
# gwalior->1->61
#
# fortpart->1->1
#
# madhya->1->4
#
# pradeshmadhya->1->1
#
# pradesh->1->3 4->8
#
# india->1->23 4->5
#
# fort->1->117 4->29
#
# locmap->1->9 4->9
#
# od->1->1 4->1
#
# posit->1->7 2->10 4->6
#
# absolut->1->6 4->6
#
# id->1->5 2->4 3->4 4->5
#
# line->1->7 2->5 3->10 4->8
#
# height->1->10 2->3 3->10 4->11
#
# pv->1->2 2->4 4->2
#
# pl->1->2 4->2
#
# top->1->10 2->6 3->11 4->13
#
# em->1->28 2->23 3->85 4->25
#
# right->1->11 2->10 3->16 4->11
#
# pr->1->2 4->2
#
# left->1->15 2->13 3->18 4->13
#
# div->1->3 3->8 4->3
#
# display->1->10 2->6 3->11 4->11
#
# inlin->1->6 2->2 3->2 4->6
#
# fortgwalior->1->1
#
# fortshow->1->1
#
# map->1->4 4->1
#
# pradeshshow->1->1
#
# indiashow->1->1
#
# coordin->1->2 2->2 4->1
#
# geo->1->5 4->5
#
# default->1->1 4->1
#
# dms->1->1 4->1
#
# dec->1->1 4->1
#
# nondefault->1->1 4->1
#
# multi->1->1 4->1
#
# punct->1->1 4->1
#
# longitud->1->1 4->1
#
# latitud->1->1 2->1 4->1
#
# white->1->3 2->2 3->2 4->4
#
# space->1->6 2->4 3->5 4->5
#
# nowrap->1->3 2->2 3->2 4->3
#
# deg->1->8 4->8
#
# typefortsit->1->1
#
# owner->1->1
#
# huna->1->2
#
# th->1->23 2->1 3->1 4->2
#
# centuri->1->20 3->1 4->1
#
# gurjara->1->2
#
# pratihara->1->4
#
# kachchhapaghata->1->4
#
# delhi->1->9
#
# sultan->1->12
#
# tomar->1->14
#
# mughal->1->14
#
# briefli->1->3
#
# under->1->6 2->6
#
# sur->1->2
#
# empir->1->8
#
# rana->1->8
#
# gohad->1->9
#
# scindia->1->11
#
# mid->1->1
#
# captur->1->8
#
# british->1->11 2->1 3->1 4->1
#
# given->1->1 2->4 3->1
#
# back->1->1 2->1 3->2
#
# central->1->3 2->6 3->5
#
# govern->1->5 4->3
#
# present->1->3 2->5 3->3 4->3
#
# open->1->3 2->3 3->2
#
# toth->1->1
#
# public->1->1 2->6 4->2
#
# yes->1->2
#
# site->1->1 2->3 4->1
#
# histori->1->8 2->4 3->1 4->2
#
# builtth->1->1
#
# renov->1->1
#
# maharaja->1->4 4->6
#
# supervis->1->1
#
# general->1->4 2->13 3->1 4->2
#
# sardar->1->1
#
# surv->1->1
#
# use->1->4 2->26 3->2 4->4
#
# materi->1->1 3->2
#
# sandston->1->4 4->1
#
# lime->1->1
#
# mortar->1->1
#
# battleswar->1->1
#
# numer->1->3 2->4
#
# event->1->2 2->1
#
# gwaliiyar->1->1
#
# qila->1->4
#
# hill->1->5 2->4 3->1
#
# near->1->5
#
# has->1->12 2->34 3->1 4->9
#
# exist->1->4 2->4 4->1
#
# at->1->24 2->37 3->25 4->10
#
# least->1->1 2->2
#
# inscript->1->5
#
# monument->1->19 4->5
#
# found->1->5 2->27 4->1
#
# within->1->8 2->11 3->1 4->7
#
# campus->1->2
#
# indic->1->3 2->5
#
# earli->1->4 2->5 3->3 4->1
#
# begin->1->2 3->2
#
# modern->1->3
#
# day->1->3 2->3 3->1 4->5
#
# consist->1->2 2->1 3->1
#
# defens->1->2 4->1
#
# structur->1->5 2->3 4->4
#
# two->1->4 2->9 3->3 4->8
#
# palac->1->20 3->2 4->18
#
# built->1->27 4->11
#
# man->1->16 2->1
#
# singh->1->25
#
# control->1->8 2->17 3->1
#
# number->1->3 2->8
#
# differ->1->1 2->13
#
# main->1->7 2->3 3->3 4->7
#
# mandir->1->23
#
# gujari->1->5
#
# mahal->1->19 4->4
#
# reign->1->2
#
# ce->1->4
#
# latter->1->1
#
# queen->1->1 3->1
#
# mrignayani->1->2
#
# oldest->1->4
#
# record->1->4 2->2
#
# zero->1->4
#
# world->1->5 2->10 3->7
#
# small->1->4 2->4 3->2 4->1
#
# templ->1->27 4->10
#
# stone->1->3 4->5
#
# symbol->1->1
#
# valu->1->1 2->3
#
# decim->1->2 2->1 3->1 4->1
#
# notat->1->1
#
# locat->1->4 2->6 3->1 4->7
#
# around->1->5 2->5 4->1
#
# year->1->9 2->14 3->4 4->2
#
# old->1->3 2->3
#
# content->1->3 2->3 3->5 4->3
#
# etymolog->1->2
#
# topographi->1->2
#
# major->1->2 2->7
#
# jain->1->11
#
# teli->1->10
#
# ka->1->9
#
# garuda->1->5
#
# sahastrabahu->1->2
#
# sas->1->5
#
# bahu->1->6
#
# gurdwara->1->3
#
# bandi->1->5
#
# chhor->1->5
#
# hathi->1->5
#
# pol->1->3
#
# karn->1->4
#
# vikram->1->5
#
# chhatri->1->4
#
# bhim->1->5
#
# museum->1->6 4->1
# other->1->7 2->14 3->6 4->4
#
# galleri->1->2
#
# refer->1->4 2->6 3->3 4->3
#
# bibliographi->1->2 2->2
#
# extern->1->2 2->3 3->2 4->2
#
# link->1->4 2->8 3->2 4->2
#
# edit->1->23 2->40 3->15 4->12
#
# fortress->1->2
#
# deriv->1->1
#
# gwalipa->1->3
#
# accord->1->5 3->1 4->1
#
# legend->1->2
#
# cure->1->2
#
# local->1->3 2->1
#
# chieftain->1->2
#
# suraj->1->4
#
# sena->1->2
#
# leprosi->1->2
#
# gratitud->1->1
#
# seen->1->3 2->5
#
# resid->1->2
#
# decemb->1->4 2->10
#
# click->1->1
#
# see->1->1 2->2 3->3
#
# detail->1->1 2->2 3->1
#
# an->1->10 2->34 3->9 4->6
#
# outcrop->1->1
#
# vindhyan->1->1
#
# solitari->1->1
#
# rocki->1->1
#
# gopach->1->5
#
# this->1->9 2->29 3->2 4->12
#
# featur->1->1 3->1 4->4
#
# thin->1->1
#
# steep->1->1
#
# geolog->1->2
#
# rang->1->2 2->8
#
# rock->1->9
#
# format->1->2 2->3 3->1 4->1
#
# ochr->1->1
#
# colour->1->1 4->1
#
# cover->1->2 4->1
#
# basalt->1->1
#
# horizont->1->1
#
# stratum->1->2
#
# feet->1->10 4->5
#
# highest->1->2 2->4
#
# point->1->2 2->2 3->9
#
# length->1->1 3->1
#
# mile->1->1
#
# km->1->1
#
# averag->1->1
#
# yard->1->1
#
# form->1->2 2->10 4->2
#
# perpendicular->1->1
#
# precipic->1->1
#
# river->1->3 2->1
#
# swarnrekha->1->1
#
# flow->1->1 2->2
#
# close->1->2 3->1
#
# courtyard->1->1
#
# maan->1->3
#
# exact->1->1
#
# period->1->5 2->5
#
# construct->1->2 4->4
#
# uncertain->1->1
#
# sen->1->2
#
# sage->1->3
#
# offer->1->1 3->2 4->1
#
# water->1->5 2->2 4->2
#
# sacr->1->1
#
# pond->1->2
#
# lie->1->1
#
# grate->1->1
#
# pal->1->3 2->1
#
# protector->1->2
#
# upon->1->1 2->5 3->1
#
# told->1->1
#
# would->1->1 2->1
#
# remain->1->2 2->3 3->2
#
# famili->1->3 2->3 4->1
#
# bear->1->1
#
# descend->1->1
#
# tej->1->1
#
# karan->1->5
#
# describ->1->2 2->5
#
# dure->1->7 2->26 3->3 4->1
#
# emperor->1->7
#
# mihirakula->1->1
#
# definit->1->1 2->4
#
# first->1->3 2->25 3->7 4->2
#
# mention->1->1
#
# histor->1->3 4->1
#
# most->1->3 2->22 3->3 4->1
#
# probabl->1->1 2->1
#
# feudatori->1->1
#
# chandela->1->1
#
# onward->1->1
#
# muslim->1->5 4->1
#
# dynasti->1->11
#
# attack->1->3 2->1 3->1
#
# sever->1->5 2->18 4->1
#
# mahmud->1->1
#
# ghazni->1->1
#
# besieg->1->1
#
# four->1->2 2->1 3->1 4->1
#
# tabaqat->1->1
#
# akbari->1->1
#
# lift->1->1 2->1
#
# sieg->1->3
#
# tribut->1->1
#
# eleph->1->3
#
# ghurid->1->1
#
# qutb->1->1
#
# al->1->2 2->16
#
# din->1->1
#
# aibak->1->1
#
# later->1->4 2->7 3->6
#
# becam->1->1 3->1
#
# recaptur->1->3
#
# iltutmish->1->1
#
# distinguish->1->1 2->1 3->1
#
# commiss->1->1
#
# sikand->1->1
#
# lodi->1->2
#
# tri->1->1 3->1
#
# unsuccess->1->1
#
# ibrahim->1->1
#
# result->1->1 2->13
#
# death->1->4 2->5 3->3
#
# ultim->1->1 2->2 3->2
#
# surrend->1->2
#
# base->1->2 2->10 3->2
#
# mani->1->5 2->3 3->3 4->1
#
# hemu->1->2
#
# campaign->1->3 4->1
#
# decad->1->1 2->2 3->2
#
# babur->1->3
#
# sher->1->1 3->3
#
# shah->1->2
#
# suri->1->1
#
# hindu->1->6 4->1
#
# last->1->3 2->4 3->3
#
# grandson->1->1
#
# akbar->1->3
#
# prison->1->5
#
# polit->1->1 3->7
#
# exampl->1->1 2->3
#
# abul->1->1
#
# kasim->1->1
#
# kamran->1->1
#
# cousin->1->1
#
# held->1->4 4->2
#
# execut->1->3 3->1
#
# ramshah->1->1
#
# tanwar->1->1
#
# taken->1->1 2->1
#
# refug->1->1
#
# mewar->1->1
#
# fought->1->1
#
# battl->1->3 3->1
#
# haldighati->1->1
#
# martyr->1->1
#
# along->1->3 2->1
#
# three->1->1 2->7 3->2
#
# includ->1->8 2->19 3->3
#
# shalivahan->1->1
#
# heir->1->1
#
# appar->1->1
#
# guru->1->18
#
# hargobind->1->12
#
# june->1->2 2->5 3->2 4->1
#
# age->1->2 2->13 3->3
#
# crown->1->2
#
# sixth->1->1
#
# sikh->1->15
#
# put->1->1
#
# sword->1->1
#
# spiritu->1->2
#
# author->1->2 2->3 3->3
#
# piri->1->1
#
# tempor->1->1
#
# miri->1->1
#
# becaus->1->3 2->7 3->3
#
# arjan->1->3
#
# jahangir->1->7
#
# veri->1->4 2->2 4->1
#
# start->1->1 2->1
#
# dedic->1->5 4->1
#
# enemi->1->1
#
# rule->1->4 2->3 3->2 4->1
#
# advis->1->1 2->3
#
# fight->1->1
#
# father->1->2 3->1
#
# hand->1->2 2->3 3->1
#
# prompt->1->1
#
# emphasis->1->1
#
# militari->1->1 3->1
#
# dimens->1->1
#
# communiti->1->1
#
# respond->1->1
#
# jail->1->2
#
# pretext->1->2
#
# fine->1->2 2->1
#
# impos->1->2
#
# paid->1->2
#
# how->1->1 2->8 3->2
#
# much->1->1 2->5
#
# spent->1->1 3->2
#
# releas->1->3 2->5
#
# either->1->2 2->2
#
# persian->1->1
#
# dabistan->1->1
#
# mazahib->1->1
#
# suggest->1->1 2->8 3->1 4->1
#
# kept->1->2 2->3 3->2
#
# twelv->1->1
#
# over->1->3 2->2
#
# camp->1->1
#
# were->1->12 2->16 3->13 4->1
#
# armi->1->2 3->4
#
# surveil->1->1
#
# tradit->1->2 2->3 3->1 4->1
#
# bondag->1->1
#
# diwali->1->1
#
# term->1->1 2->6 3->1
#
# diva->1->1
#
# festiv->1->1 4->1
#
# aurangzeb->1->4
#
# brother->1->1
#
# murad->1->1
#
# bakhsh->1->1
#
# nephew->1->1
#
# sulaiman->1->1
#
# shikoh->1->2
#
# kill->1->1 2->7
#
# took->1->3 2->2 3->1
#
# sipihr->1->1
#
# imprison->1->3
#
# muhammad->1->1
#
# januari->1->2 2->9 3->3
#
# maratha->1->9
#
# territori->1->3
#
# declin->1->1 2->2 3->1
#
# northern->1->1 3->1
#
# incurs->1->1
#
# north->1->8 2->5 3->1
#
# raid->1->3
#
# peshwa->1->1
#
# bajirao->1->1
#
# defeat->1->1
#
# mahadaji->1->1
#
# shind->1->1
#
# chhatar->1->1
#
# east->1->5 2->1 4->2
#
# compani->1->5
#
# august->1->1 2->15 3->2
#
# forc->1->1 2->1 3->3 4->1
#
# captain->1->1
#
# popham->1->1
#
# bruce->1->1
#
# nighttim->1->1
#
# scale->1->1 2->1
#
# wall->1->3 4->2
#
# grenadi->1->1
#
# sepoy->1->2
#
# both->1->2 2->7 3->5 4->1
#
# side->1->4 2->1 3->32 4->1
#
# suffer->1->1 2->2 3->1
#
# fewer->1->1 2->1
#
# than->1->1 2->15
#
# wound->1->1
#
# total->1->1 3->1
#
# governor->1->1
#
# warren->1->1 3->2
#
# restor->1->2
#
# did->1->1 2->2
#
# interven->1->1
#
# hostil->1->1
#
# daulat->1->1
#
# rao->1->2
#
# sindhia->1->1
#
# anglo->1->1
#
# war->1->1 3->5 4->1
#
# chang->1->1 2->23 3->1
#
# between->1->3 2->21
#
# maharajpur->1->1
#
# occupi->1->3
#
# state->1->4 2->19 3->4
#
# upris->1->1
#
# station->1->2
#
# rebel->1->1
#
# against->1->1 2->5
#
# vassal->1->1
#
# jayajirao->1->2
#
# loyal->1->1
#
# reward->1->1
#
# some->1->1 2->18 3->3
#
# retain->1->1
#
# complet->1->1 2->1 3->1
#
# no->1->7 2->17 3->7 4->4
#
# longer->1->1 2->2
#
# strateg->1->1
#
# therefor->1->1 2->5
#
# continu->1->1 2->1 3->3
#
# until->1->1 2->4 3->2
#
# independ->1->1 2->2
#
# jai->1->2
#
# vila->1->2
#
# cut->1->4 2->1
#
# tirthankara->1->4
#
# premis->1->1
#
# maintain->1->1 4->1
#
# hous->1->2 2->2 3->2 4->3
#
# tank->1->3 4->1
#
# jahan->1->1
#
# area->1->6 2->5
#
# squar->1->1 4->2
#
# kilometr->1->1 4->2
#
# sq->1->1
#
# mi->1->1 4->2
#
# rise->1->1 2->2 4->1
#
# metr->1->2 4->3
#
# ft->1->2 4->3
#
# rampart->1->1
#
# edg->1->1
#
# connect->1->1 2->1 4->1
#
# six->1->1 2->3
#
# bastion->1->2 4->1
#
# tower->1->3 4->8
#
# profil->1->1 2->1
#
# irregular->1->1
#
# due->1->2 2->10
#
# undul->1->1
#
# ground->1->1 4->1
#
# beneath->1->1
#
# citat->1->19 2->12 3->8 4->8
#
# need->1->12 2->8 3->1
#
# gate->1->10 4->15
#
# northeast->1->2
#
# access->1->4 4->1
#
# ramp->1->1
#
# southwest->1->1
#
# entranc->1->2 4->2
#
# ornat->1->1
#
# pul->1->1
#
# badalgarh->1->1
#
# citadel->1->1
#
# end->1->1 3->2
#
# refurbish->1->2
#
# reservoir->1->1 2->1
#
# could->1->2 2->3 3->1
#
# provid->1->1 2->3 4->1
#
# strong->1->1 2->1
#
# garrison->1->1
#
# requir->1->1
#
# hatnot->1->5
#
# style->1->17 2->10 3->11 4->13
#
# ital->1->1 3->1
#
# bottom->1->4 2->3 3->4 4->3
#
# normal->1->2 2->7 3->1 4->1
#
# articl->1->3 2->1
#
# siddhach->1->3
#
# cave->1->4
#
# eleven->1->1 2->1
#
# insid->1->4 2->4 3->4 4->2
#
# southern->1->1
#
# intric->1->1
#
# carv->1->6
#
# tallest->1->1
#
# idol->1->13
#
# rishabhanatha->1->1
#
# adinatha->1->3
#
# st->1->6
#
# inch->1->4
#
# urvahi->1->4
#
# statu->1->5 4->1
#
# urwai->1->1
#
# entir->1->1 2->1
#
# divid->1->1 2->1
#
# five->1->1 2->1 4->2
#
# group->1->8 2->11 3->7 4->6
#
# west->1->4 3->37 4->3
#
# south->1->4 2->1 4->1
#
# tirthankar->1->1
#
# padmasana->1->2
#
# postur->1->3
#
# kayotsarga->1->1
#
# pillar->1->3
#
# largest->1->1
#
# outsid->1->2 4->4
#
# suparshvanatha->1->1
#
# paththar->1->1
#
# ki->1->1
#
# bavadi->1->1
#
# bhagwan->1->3
#
# hilli->1->1
#
# artist->1->1 3->1
#
# dungar->1->1
#
# keerti->1->1
#
# beauti->1->1
#
# miracul->1->1
#
# weasel->1->1
#
# colossus->1->2
#
# parsvanath->1->2
#
# padmasan->1->1
#
# breadth->1->1
#
# babar->1->1
#
# order->1->1 4->1
#
# soldier->1->2
#
# break->1->4 2->3 3->5 4->3
#
# stroke->1->1
#
# thumb->1->1
#
# miracl->1->1
#
# invad->1->1 2->1
#
# compel->1->1
#
# run->1->1 2->1
#
# destroy->1->2 2->2 3->1
#
# broken->1->1
#
# fragment->1->1
#
# spread->1->1 2->8
#
# kshetra->1->1
#
# parsvanatha->1->1
#
# wide->1->1 2->6
#
# togeth->1->1 3->1
#
# precept->1->1
#
# where->1->3 2->9 3->2 4->1
#
# shri->1->2
#
# supratishtha->1->1
#
# kevali->1->1
#
# attain->1->1
#
# nirvana->1->1
#
# more->1->1 2->19
#
# invas->1->2 2->1
#
# de->1->6 2->7 3->1
#
# face->1->1 2->1 4->2
#
# spite->1->1
#
# jaina->1->1
#
# sculptur->1->4
#
# surviv->1->1 2->7
#
# fair->1->2 4->1
#
# good->1->1 3->3
#
# condit->1->1 2->3
#
# so->1->1 2->5 3->3
#
# former->1->1
#
# splendour->1->1
#
# mihira->1->2
#
# bhoja->1->2
#
# part->1->1 2->7 3->4 4->2
#
# blend->1->1
#
# indian->1->11
#
# architectur->1->6 4->5
#
# rectangular->1->1
#
# shrine->1->1
#
# pavilion->1->2 4->1
#
# mandapa->1->1
#
# barrel->1->2
#
# vault->1->2
#
# roof->1->2
#
# masonri->1->1
#
# nagara->1->1
#
# nich->1->1
#
# outer->1->1 3->1
#
# onc->1->3 2->4
#
# chandrashala->1->2
#
# horsesho->1->1
#
# arch->1->4 4->1
#
# ventil->1->1
#
# compar->1->1 2->2
#
# trefoil->1->1
#
# honeycomb->1->1
#
# design->1->1 2->1 4->1
#
# seri->1->2 2->1 3->2
#
# reced->1->1
#
# door->1->3
#
# torana->1->1
#
# archway->1->1
#
# sculpt->1->1
#
# goddess->1->1 4->2
#
# romant->1->1 3->1
#
# coupl->1->1 3->1
#
# foliat->1->1
#
# decor->1->4 2->2 3->2 4->2
#
# vertic->1->1 3->2
#
# band->1->1
#
# simpl->1->1 2->1
#
# fashion->1->1
#
# figur->1->1 2->1
#
# bad->1->1
#
# damag->1->2 2->3
#
# disc->1->1
#
# repres->1->1 2->1 4->2
#
# dama->1->1
#
# laka->1->1
#
# finial->1->1
#
# shikhara->1->1
#
# origin->1->2 2->38 3->12
#
# vishnu->1->3
#
# extens->1->2 2->1
#
# shiva->1->3 4->2
#
# instal->1->1
#
# linga->1->1 4->1
#
# keep->1->1
#
# vaishnava->1->1
#
# motif->1->1
#
# mixtur->1->1
#
# hindi->1->1
#
# oil->1->1
#
# pyramid->1->1
#
# shape->1->2 2->2 4->2
#
# red->1->3 2->2 3->1 4->2
#
# stori->1->1 3->37
#
# beam->1->1
#
# sahib->1->2
#
# arrest->1->1
#
# captiv->1->2
#
# dev->1->1
#
# ji->1->1
#
# surjit->1->1
#
# gandhi->1->1
#
# raja->1->4 4->5
#
# hostag->1->1
#
# million->1->1 2->1
#
# rupe->1->1
#
# oppos->1->1 2->2
#
# dismay->1->1
#
# lose->1->1
#
# mentor->1->1
#
# get->1->1 2->3 3->5 4->1
#
# request->1->1
#
# freed->1->1
#
# allow->1->1 2->2
#
# free->1->3 2->6 3->3 4->2
#
# leav->1->1
#
# got->1->1
#
# special->1->1
#
# gown->1->1
#
# stitch->1->1
#
# hem->1->2
#
# caught->1->1 3->2
#
# cloak->1->1
#
# often->1->1 2->7
#
# paint->1->2 4->2
#
# effect->1->1 2->21
#
# tile->1->1
#
# turquois->1->1
#
# green->1->2 2->1 3->1 4->1
#
# yellow->1->1
#
# geometr->1->1
#
# pattern->1->1 2->4 4->1
#
# hathiya->1->1
#
# paur->1->1
#
# southeast->1->1 2->1
#
# seven->1->1 2->1
#
# life->1->1 2->7 3->4
#
# adorn->1->1
#
# cylindr->1->1
#
# cupola->1->2
#
# dome->1->3
#
# parapet->1->1
#
# pictur->1->1 2->1 3->3
#
# signific->1->1 2->15
#
# kirti->1->1
#
# known->1->2 2->5 4->4
#
# host->1->1 2->40
#
# vikramaditya->1->1
#
# elder->1->1 3->1
#
# mansingh->1->1
#
# devote->1->1
#
# re->1->1 2->1 3->2
#
# establish->1->1 3->1 4->1
#
# front->1->1 3->1 4->1
#
# memori->1->2 3->4
#
# successor->1->1
#
# chhatra->1->2
#
# satrap->1->1
#
# ali->1->1
#
# khan->1->1 2->2
#
# bhimtal->1->2
#
# lake->1->1
#
# archaeolog->1->6
#
# gujar->1->1
#
# demand->1->1
#
# separ->1->1 2->1
#
# herself->1->1
#
# regular->1->1
#
# suppli->1->1
#
# through->1->1 2->9 3->2
#
# aqueduct->1->1
#
# nearbi->1->1 4->1
#
# rai->1->2
#
# convert->1->1 2->2
#
# rare->1->1 2->7
#
# artefact->1->1
#
# date->1->1 4->1
#
# nd->1->1 2->1
#
# bc->1->1
#
# miniatur->1->1
#
# salabhanjika->1->1
#
# terracotta->1->1
#
# item->1->1
#
# replica->1->1
#
# fresco->1->1
#
# bagh->1->1 4->2
#
# school->1->2 3->1 4->1
#
# exclus->1->1 4->1
#
# nobl->1->1 2->1
#
# madho->1->1
#
# interior->1->1
#
# view->1->2 2->1 3->1 4->1
#
# room->1->1 2->1
#
# morn->1->1
#
# gurudwara->1->1
#
# shahib->1->1
#
# reflist->1->12 2->12 3->12 4->12
#
# list->1->10 2->10 3->19 4->10
#
# type->1->7 2->20 3->7 4->7
#
# inherit->1->9 2->9 3->9 4->9
#
# column->1->8 2->8 3->11 4->8
#
# ol->1->3 2->3 3->4 4->3
#
# li->1->2 2->4 3->6 4->2
#
# page->1->5 2->2 3->4 4->1
#
# avoid->1->2 2->6 3->4 4->2
#
# upper->1->4 2->4 3->5 4->4
#
# alpha->1->4 2->4 3->4 4->4
#
# roman->1->4 2->4 3->4 4->4
#
# lower->1->6 2->13 3->6 4->6
#
# greek->1->2 2->3 3->2 4->2
#
# jump->1->7 2->58 4->3
#
# up->1->8 2->63 3->1 4->3
#
# paul->1->4 2->4 3->2
#
# schelling->1->4
#
# robert->1->4 2->7 3->6
#
# salkin->1->4
#
# you->1->1 2->2 3->6
#
# visit->1->1 2->1 4->1
#
# smithsonian->1->1
#
# magazin->1->1 2->1
#
# wrap->1->1 2->1 3->1 4->1
#
# quot->1->1 2->1 3->1 4->1
#
# target->1->1 2->7 3->1 4->1
#
# rgba->1->1 2->1 3->1 4->1
#
# lock->1->11 2->11 3->11 4->11
#
# cs->1->12 2->12 3->12 4->12
#
# linear->1->4 2->4 3->4 4->4
#
# gradient->1->4 2->4 3->4 4->4
#
# url->1->5 2->6 3->5 4->4
#
# urlwikipediacommon->1->1 2->1 3->1 4->1
#
# centerpx->1->4 2->4 3->4 4->4
#
# limit->1->2 2->5 3->2 4->5
#
# registr->1->2 2->2 3->2 4->2
#
# urlwikipediacommonsdd->1->1 2->1 3->1 4->1
#
# gray->1->1 2->1 3->2 4->1
#
# alt->1->2 2->2 3->2 4->2
#
# svg->1->2 2->2 3->2 4->2
#
# subscript->1->2 2->2 3->2 4->2
#
# urlwikipediacommonsaaa->1->1 2->1 3->1 4->1
#
# ws->1->1 2->1 3->1 4->1
#
# icon->1->1 2->1 3->1 4->1
#
# urlwikipediacommonsc->1->1 2->1 3->1 4->1
#
# wikisourc->1->1 2->1 3->1 4->1
#
# logo->1->1 2->1 3->1 4->1
#
# code->1->1 2->1 3->1 4->1
#
# hidden->1->1 2->1 3->1 4->1
#
# error->1->2 2->5 3->3 4->2
#
# visibl->1->1 2->1 3->1 4->1
#
# maint->1->1 2->1 3->1 4->1
#
# kern->1->2 2->2 3->2 4->2
#
# selflink->1->1 2->1 3->1 4->1
#
# weight->1->2 2->2 3->6 4->2
#
# joseph->1->1
#
# georg->1->3 2->2 3->6
#
# gheverghes->1->1
#
# mathemat->1->1
#
# engag->1->1 2->1 3->1
#
# ancient->1->3 4->1
#
# scientif->1->1 2->3
#
# isbn->1->19 2->10 3->7
#
# path->1->1
#
# we->1->1 2->1 3->5
#
# circular->1->1 2->1
#
# termin->1->1
#
# fodor->1->4
#
# et->1->1 2->13
#
# mckay->1->2
#
# googl->1->2 4->1
#
# book->1->3 3->3
#
# novemb->1->2 2->6 3->2
#
# william->1->2 2->1 3->5
#
# curti->1->1 3->1
#
# eugen->1->1
#
# oldham->1->1
#
# manual->1->1 2->1
#
# cambridg->1->1
#
# univers->1->8 2->1 3->3
#
# press->1->9 2->4 3->3 4->1
#
# konstantin->1->2
#
# nossov->1->2
#
# brain->1->2 2->12
#
# delf->1->2
#
# sisirkumar->1->3
#
# mitra->1->3 2->1
#
# pp->1->8 2->3 3->8
#
# torton->1->1
#
# gazett->1->1 4->1
#
# nativ->1->1
#
# contin->1->1
#
# volum->1->3
#
# allen->1->3 3->5
# co->1->1 3->1
#
# loui->1->1 2->1
#
# fenech->1->1
#
# martyrdom->1->1
#
# oxford->1->2
#
# hs->1->2
#
# singha->1->1
#
# studi->1->1 2->31
#
# hemkunt->1->1
#
# syan->1->1
#
# milit->1->1
#
# seventeenth->1->1
#
# ib->1->1
#
# tauri->1->1
#
# mahajan->1->1
#
# chand->1->1
#
# new->1->2 2->9 3->25
#
# phylli->1->1
#
# jestic->1->1
#
# holi->1->1
#
# peopl->1->1 2->22 3->1 4->2
#
# cross->1->1 2->1
#
# cultur->1->4 2->5 3->1
#
# encyclopedia->1->1 2->1
#
# abc->1->1
#
# clio->1->1
#
# arvind->1->1
#
# mandair->1->1
#
# sikhism->1->3
#
# guid->1->3
#
# perplex->1->1
#
# black->1->1 2->2 3->1
#
# fauja->1->1
#
# harban->1->1
#
# ed->1->4 2->5
#
# encyclopaedia->1->1
#
# punjabi->1->2
#
# retriev->1->1 2->23 3->2 4->3
#
# review->1->1 2->19 3->2
#
# issu->1->1
#
# centr->1->1 4->1
#
# eleanor->1->1
#
# nesbitt->1->1
#
# introduct->1->2
#
# toni->1->2 3->15
#
# mcclenaghan->1->2
#
# archiv->1->1 2->42 3->9
#
# ghostarch->1->1
#
# wayback->1->1 2->4 3->4
#
# machin->1->1 2->4 3->4
#
# gvaaliyr->1->1
#
# kaa->1->1
#
# itihaa->1->1
#
# youtub->1->1
#
# kamat->1->1
#
# potpourri->1->1
#
# webpag->1->1
#
# kurt->1->1
#
# titz->1->1
#
# klaus->1->1 2->1
#
# bruhn->1->1
#
# jainism->1->1
#
# pictori->1->1 3->1
#
# religion->1->1 3->1
#
# non->1->1 2->4
#
# violenc->1->1
#
# motil->1->2
#
# banarsidass->1->2
#
# cunningham->1->2
#
# survey->1->4 2->12
#
# bhopal->1->1
#
# circl->1->1
#
# samaj->1->1
#
# bajpai->1->1
#
# gopachala->1->1
#
# bharatiya->1->1
#
# jnanpith->1->1
#
# michel->1->1
#
# chicago->1->1 2->1
#
# footnot->1->1
#
# margaret->1->1
#
# prosser->1->1
#
# ornament->1->2
#
# delawar->1->2
#
# asi->1->1
#
# report->1->3 2->13 3->1
#
# sengupta->1->1
#
# guatam->1->1
#
# lambah->1->1
#
# abha->1->1
#
# narain->1->1
#
# custodian->1->1
#
# past->1->1 4->5
#
# ministri->1->1
#
# henri->1->1 3->1
#
# hardi->1->1
#
# cole->1->1
#
# curat->1->2
#
# preserv->1->1
#
# nation->1->1 2->12 3->4 4->1
#
# simla->1->1
#
# branch->1->1 3->1
#
# castl->1->3
#
# illustr->1->1
#
# osprey->1->1
#
# intern->1->1 2->10 3->1
#
# dictionari->1->1
#
# asia->1->1 2->2
#
# oceania->1->1
#
# vol->1->1
#
# routledgetaylor->1->1
#
# franci->1->1 2->1 3->1
#
# khajuraho->1->1
#
# medal->1->1
#
# lancer->1->1
#
# tillotson->1->1
#
# rajput->1->2
#
# develop->1->1 2->18 3->1
#
# yale->1->1
#
# haven->1->1
#
# london->1->1 2->2 3->1 4->2
#
# hardback->1->1
#
# wikimedia->1->1 4->1
#
# common->1->2 2->10 4->1
#
# media->1->1 3->1 4->1
#
# relat->1->1 2->9 3->1 4->1
#
# interest->1->1
#
# fact->1->1 3->1
#
# travel->1->1 2->2 3->1
#
# wikivoyag->1->1
#
# navbox->1->41 2->41 3->41 4->41
#
# box->1->2 2->4 3->4 4->2
#
# solid->1->3 2->7 3->8 4->3
#
# aab->1->1 2->1 3->1 4->1
#
# inner->1->1 2->1 3->1 4->2
#
# subgroup->1->5 2->5 3->7 4->5
#
# abovebelow->1->4 2->4 3->4 4->4
#
# fdfdfd->1->3 2->3 3->3 4->3
#
# tr->1->8 2->8 3->8 4->8
#
# ccf->1->1 2->1 3->1 4->1
#
# ddf->1->1 2->1 3->1 4->1
#
# eeff->1->1 2->1 3->1 4->1
#
# even->1->1 2->3 3->2 4->1
#
# fff->1->1 2->1 3->2 4->1
#
# odd->1->1 2->1 3->1 4->1
#
# hlist->1->6 2->6 3->6 4->6
#
# td->1->3 2->3 3->3 4->3
#
# dl->1->2 2->2 3->3 4->2
#
# ul->1->3 2->9 3->8 4->3
#
# block->1->2 2->2 3->2 4->2
#
# collaps->1->1 2->1 3->5 4->1
#
# boxtext->1->1 2->1 3->1 4->1
#
# bracket->1->2 2->2 3->2 4->2
#
# span->1->1 2->1 3->3 4->1
#
# abbr->1->2 2->2 3->2 4->2
#
# mini->1->2 2->2 3->2 4->2
#
# variant->1->1 2->1 3->1 4->1
#
# cap->1->1 2->1 3->1 4->1
#
# cursor->1->1 2->1 3->1 4->1
#
# ct->1->2 2->2 3->2 4->2
#
# vte->1->3 2->1 3->5 4->1
#
# topic->1->2 2->1
#
# tomara->1->1
#
# geographi->1->1
#
# lashkar->1->1
#
# morar->1->1
#
# canton->1->1
#
# thatipur->1->1
#
# build->1->1 4->2
#
# chaturbhuj->1->1
#
# mountain->1->1
#
# transport->1->1 2->2
#
# airport->1->1
#
# railway->1->2
#
# light->1->1 3->2
#
# economi->1->1
#
# trade->1->1
#
# civic->1->1
#
# municip->1->1
#
# corpor->1->1 3->1
#
# gharana->1->1
#
# star->1->1 2->1 3->7
#
# categori->1->1
#
# indiavijayanagara->1->1
#
# ginge->1->3
#
# bangalor->1->1
#
# udayagiri->1->2 4->1
#
# vellor->1->1
#
# deccan->1->1
#
# ahmednagar->1->1
#
# daulatabad->1->1
#
# gawilghur->1->1
#
# golconda->1->1
#
# narnala->1->1
#
# panhala->1->2
#
# gujarat->1->1
#
# bhadra->1->1
#
# aligarh->1->1
#
# bandhavgarh->1->2
#
# hathra->1->1
#
# mubarak->1->1
#
# siri->1->1
#
# tughlaqabad->1->1
#
# salimgarh->1->1
#
# nayak->1->1
#
# chitradurga->1->1
#
# bekal->1->2
#
# dindigul->1->1
#
# tiruchirap->1->1
#
# chandragiri->1->1 4->1
#
# hosdurg->1->1
#
# malwa->1->1
#
# mandsaur->1->2
#
# mandavgadh->1->1
#
# faruqi->1->1
#
# asirgarh->1->2
#
# lale->1->1
#
# thalner->1->1
#
# achalgarh->1->1
#
# amber->1->1
#
# bhangarh->1->1
#
# chittor->1->1
#
# jaigarh->1->1
#
# jaisalm->1->1
#
# jalor->1->1
#
# junagarh->1->1
#
# kankwadi->1->1
#
# kumbhalgarh->1->1
#
# nahargarh->1->1
#
# pithora->1->1
#
# taragarh->1->1
#
# lal->1->1
#
# kot->1->1
#
# kalinjar->1->1
#
# hinglajgarh->1->3
#
# mehrangarh->1->1
#
# narwar->1->2
#
# senapati->1->1
#
# sabalgarh->1->2
#
# kangra->1->1
#
# ranthambor->1->1
#
# bhatner->1->1
#
# dongri->1->1
#
# harishchandragad->1->1
#
# kolaba->1->1
#
# lohagad->1->1
#
# sudhagad->1->1
#
# sinhagad->1->1
#
# tikona->1->1
#
# pratapgad->1->1
#
# vishalgad->1->1
#
# rajgad->1->1
#
# sindhudurg->1->1
#
# vijaydurg->1->1
#
# shivneri->1->1
#
# raigad->1->1
#
# gajendragarh->1->1
#
# shaniwar->1->1
#
# wada->1->1
#
# jhansi->1->1
#
# manora->1->1
#
# visapur->1->1
#
# sadashivgad->1->1
#
# purana->1->1
#
# chanderi->1->2
#
# agra->1->1
#
# allahabad->1->1
#
# fatehpur->1->1
#
# sikri->1->1
#
# akola->1->1
#
# hari->1->1 2->1
#
# parbat->1->1
#
# ramnagar->1->1
#
# jat->1->1
#
# bawana->1->1
#
# lohagarh->1->1
#
# nahar->1->1
#
# mysor->1->1
#
# devanah->1->1
#
# palakkad->1->1
#
# sankagiri->1->1
#
# siddi->1->1
#
# murud->1->1
#
# janjira->1->1
#
# belapur->1->1
#
# underi->1->1
#
# travancor->1->1
#
# vattakottai->1->1
#
# portugues->1->1
#
# bassein->1->1
#
# bombay->1->2
#
# mahim->1->2
#
# arnala->1->1
#
# castella->1->1
#
# aguada->1->2
#
# diu->1->2
#
# surat->1->1
#
# fortim->1->2
#
# mar->1->2 2->2
#
# simbor->1->1
#
# emmanuel->1->1
#
# anjediva->1->2
#
# korlai->1->1
#
# madh->1->1
#
# thoma->1->1 3->2
#
# tangasseri->1->1
#
# angelo->1->1
#
# pallipuram->1->1
#
# tiracol->1->1
#
# cranganor->1->1
#
# ghodbund->1->1
#
# fortaleza->1->2
#
# chaul->1->1
#
# ponda->1->1
#
# chapora->1->1
#
# sao->1->2
#
# sebastiao->1->1
#
# tivim->1->1
#
# cabo->1->1
#
# rama->1->1 4->2
#
# corjuem->1->1
#
# mormugao->1->1
#
# rachol->1->1
#
# tiago->1->1
#
# banastarim->1->1
#
# jamrud->1->1
#
# kamlah->1->1
#
# multan->1->1
#
# harkishangarh->1->1
#
# lahor->1->1
#
# raj->1->1 4->1
#
# anchuthengu->1->1
#
# riwa->1->1
#
# wor->1->1
#
# mazagon->1->1
#
# sion->1->1
#
# hillock->1->1
#
# sewri->1->1
#
# tellicherri->1->1
#
# david->1->1 3->4
#
# chunar->1->1
#
# rohtasgarh->1->1
#
# munger->1->1
#
# eastern->1->1 2->2
#
# ganga->1->1
#
# barabati->1->1
#
# raibania->1->1
#
# ahom->1->1
#
# talat->1->1
#
# ghar->1->3
#
# kareng->1->1
#
# garchuk->1->1
#
# lachit->1->1
#
# garh->1->2
#
# kakatiya->1->1
#
# warang->1->1
#
# bahmani->1->1
#
# bidar->1->1
#
# gulbarga->1->1
#
# ahilya->1->1
#
# bajrangarh->1->1
#
# dhar->1->1 2->1
#
# kundar->1->1
#
# ginnorgarh->1->1
#
# madan->1->1
#
# mandu->1->1
#
# complex->1->2 2->1
#
# orchha->1->1
#
# raisen->1->1
#
# utila->1->1
#
# toxoplasmosi->2->151
#
# parasit->2->76
#
# diseas->2->33
#
# medic->2->7
#
# toxoplasmosist->2->1
#
# gondii->2->178
#
# tachyzoit->2->14
#
# specialti->2->1
#
# infecti->2->13
#
# symptom->2->17
#
# pregnanc->2->22
#
# birth->2->7
#
# defect->2->1
#
# causestoxoplasma->2->1
#
# risk->2->40
#
# factor->2->22
#
# eat->2->5
#
# poor->2->6
#
# cook->2->8 3->1
#
# food->2->10
#
# exposur->2->12
#
# infect->2->196
#
# cat->2->67
#
# fece->2->10
#
# diagnost->2->5
#
# method->2->10
#
# blood->2->16
#
# test->2->41
#
# amniot->2->5
#
# fluid->2->9
#
# treatmentdur->2->1
#
# spiramycin->2->6
#
# pyrimethaminesulfadiazin->2->3
#
# folin->2->4
#
# acid->2->6
#
# frequencyup->2->1
#
# case->2->17 3->1
#
# congenit->2->35
#
# caus->2->23
#
# toxoplasma->2->120
#
# apicomplexan->2->3
#
# usual->2->7
#
# obvious->2->3 3->1
#
# adult->2->6
#
# occasion->2->2
#
# few->2->5
#
# week->2->13 3->1
#
# month->2->22 3->2
#
# mild->2->2
#
# flu->2->2
#
# like->2->16 3->1
#
# muscl->2->5
#
# ach->2->2
#
# tender->2->1
#
# lymph->2->6
#
# node->2->6
#
# problem->2->6
#
# weak->2->2
#
# immun->2->26
#
# system->2->23
#
# seizur->2->4
#
# occur->2->15
#
# affect->2->11
#
# contain->2->7
#
# cyst->2->18
#
# babi->2->8 3->6
#
# transfus->2->1
#
# otherwis->2->2
#
# reproduc->2->1
#
# sexual->2->2
#
# onli->2->8 3->1
#
# howev->2->13 3->3 4->1
#
# warm->2->4
#
# anim->2->24 3->1
#
# human->2->40
#
# diagnosi->2->22
#
# typic->2->3
#
# antibodi->2->31
#
# pregnant->2->16
#
# dna->2->5
#
# prevent->2->17
#
# prepar->2->2 3->1
#
# recommend->2->6
#
# clean->2->2
#
# litter->2->4
#
# must->2->1
#
# wear->2->2
#
# glove->2->2
#
# wash->2->1
#
# treatment->2->17
#
# healthi->2->8
#
# half->2->1
#
# popul->2->13
#
# unit->2->18 3->3
#
# approxim->2->4
#
# charl->2->1 3->1
#
# nicoll->2->6
#
# manceaux->2->6
#
# organ->2->13
#
# transmiss->2->24
#
# confirm->2->3
#
# tentat->2->1
#
# evid->2->9
#
# behavior->2->33
#
# toclimit->2->6
#
# toclevel->2->6
#
# sign->2->4 4->2
#
# acut->2->17
#
# latent->2->23
#
# skin->2->3
#
# parasitolog->2->31
#
# precaut->2->2
#
# epidemiolog->2->13
#
# societi->2->4 4->3
#
# crazi->2->7
#
# ladi->2->6
#
# notabl->2->3 3->1
#
# livestock->2->4
#
# pig->2->7
#
# sheep->2->6
#
# chicken->2->7
#
# cattl->2->3
#
# hors->2->7
#
# domest->2->7
#
# rodent->2->12
#
# marin->2->3
#
# mammal->2->5
#
# giant->2->6
#
# panda->2->6
#
# research->2->17
#
# mental->2->3
#
# health->2->15 3->1
#
# neurolog->2->11
#
# disord->2->21
#
# traffic->2->4
#
# accid->2->5
#
# climat->2->5
#
# stage->2->4 3->4
#
# asymptomat->2->3
#
# manifest->2->1
#
# influenza->2->1
#
# swollen->2->2
#
# headach->2->2
#
# fever->2->3
#
# pain->2->1
#
# fulli->2->3
#
# function->2->9 4->2
#
# follow->2->9 3->4
#
# weaken->2->3
#
# experi->2->3 3->3
#
# confus->2->1
#
# lung->2->4
#
# resembl->2->1
#
# tuberculosi->2->2
#
# pneumocysti->2->2
#
# jiroveci->2->1
#
# pneumonia->2->1 3->2
#
# opportunist->2->2
#
# aid->2->8
#
# chorioretin->2->6
#
# inflamm->2->2
#
# retina->2->3
#
# ocular->2->2
#
# young->2->2
#
# children->2->7 3->1
#
# immunocompromis->2->4
#
# hivaid->2->2
#
# chemotherapi->2->2
#
# recent->2->6 4->1
#
# receiv->2->4 3->2
#
# transplant->2->12
#
# enceph->2->2
#
# necrot->2->1
#
# retinochoroid->2->1
#
# infant->2->6
#
# via->2->6
#
# placent->2->3
#
# born->2->6 3->3
#
# nasal->2->1
#
# malform->2->1
#
# complic->2->2 3->1
#
# newborn->2->4
#
# toxoplasm->2->3
#
# trophozoit->2->1
#
# various->2->4 3->1
#
# tissu->2->20
#
# cerebrospin->2->3
#
# neck->2->1
#
# chin->2->1
#
# armpit->2->1
#
# groin->2->1
#
# swell->2->1
#
# initi->2->3
#
# persist->2->9
#
# recur->2->1
#
# antiparasit->2->1
#
# singl->2->1
#
# multipl->2->4
#
# enlarg->2->1
#
# resolv->2->1
#
# quarter->2->1
#
# substanti->2->1
#
# absenc->2->1
#
# easili->2->1
#
# produc->2->8 3->7
#
# readili->2->2
#
# observ->2->8 3->1
#
# immunocompet->2->3
#
# enter->2->3
#
# phase->2->6
#
# bradyzoit->2->8
#
# lesion->2->5
#
# alveolar->2->1
#
# mimic->2->2
#
# jirovecii->2->1
#
# heart->2->3 3->2 4->1
#
# skelet->2->1
#
# nervous->2->5
#
# cns->2->5
#
# lifetim->2->3
#
# womb->2->1
#
# serolog->2->13
#
# estim->2->6
#
# global->2->8
#
# expos->2->3
#
# chronic->2->13
#
# rate->2->12
#
# countri->2->10 4->1
#
# associ->2->20
#
# burden->2->3
#
# neural->2->1
#
# alter->2->16
#
# subtl->2->2
#
# gender->2->4 3->1
#
# depend->2->12
#
# increas->2->25
#
# motor->2->1
#
# vehicl->2->1
#
# collis->2->1
#
# acquir->2->4
#
# roseola->2->1
#
# erythema->2->1
#
# multiform->2->1
#
# erupt->2->1
#
# prurigo->2->1
#
# nodul->2->1
#
# urticaria->2->1
#
# maculopapular->2->1
#
# punctat->2->1
#
# macul->2->1
#
# ecchymos->2->1
#
# blueberri->2->1
#
# muffin->2->1
#
# cutan->2->2
#
# epidermi->2->2
#
# level->2->10
#
# mm->2->1
#
# bow->2->2
#
# nucleus->2->3
#
# third->2->4
#
# identifi->2->7 3->1
#
# electron->2->1
#
# microscopi->2->1
#
# giemsa->2->1
#
# stain->2->3
#
# cytoplasm->2->1
#
# show->2->14 3->5
#
# blue->2->1
#
# lifecycl->2->2
#
# adopt->2->1
#
# respons->2->18
#
# rapid->2->1
#
# tachyzo->2->1
#
# merozoit->2->3
#
# descript->2->1
#
# convey->2->1
#
# precis->2->1
#
# natur->2->8
#
# prolifer->2->2
#
# intracellular->2->3
#
# trigger->2->2
#
# pressur->2->1
#
# bradyzo->2->1
#
# antibiot->2->7
#
# lifespan->2->1
#
# activ->2->15 3->2
#
# quick->2->1
#
# individu->2->8 3->1
#
# fetus->2->15
#
# lack->2->4
#
# rampant->2->1
#
# balanc->2->3
#
# achiev->2->1 3->1
#
# manipul->2->3
#
# reduc->2->7 3->1
#
# enhanc->2->2
#
# reproduct->2->2
#
# advantag->2->1
#
# cell->2->26 3->2
#
# resist->2->6
#
# process->2->5
#
# parasitophor->2->2
#
# vacuol->2->2
#
# membran->2->4
#
# encapsul->2->1
#
# endolysosom->2->1
#
# mitochondria->2->1
#
# endoplasm->2->1
#
# reticulum->2->1
#
# rop->2->1
#
# protein->2->11
#
# bulb->2->1
#
# rhoptri->2->1
#
# organell->2->1
#
# transloc->2->1
#
# surfac->2->2
#
# stat->2->1
#
# pathway->2->4
#
# modul->2->3
#
# express->2->6
#
# cytokin->2->2
#
# transcript->2->3
#
# bind->2->1
#
# inactiv->2->1
#
# irg->2->1
#
# among->2->9 3->2
#
# addit->2->3 3->2
#
# strain->2->3
#
# secret->2->2
#
# gra->2->1
#
# nf->2->1
#
# kb->2->1
#
# upregul->2->1
#
# pro->2->4
#
# inflammatori->2->1
#
# il->2->1
#
# abil->2->5
#
# genotyp->2->4
#
# virul->2->7
#
# influenc->2->6
#
# anti->2->8
#
# apoptot->2->2
#
# mechan->2->9
#
# replic->2->3
#
# apoptosi->2->6
#
# disrupt->2->3
#
# effector->2->3
#
# bax->2->2
#
# bak->2->1
#
# conform->2->1
#
# cellular->2->2
#
# compart->2->1
#
# doe->2->4
#
# downregul->2->3
#
# autophagi->2->3
#
# decreas->2->7
#
# uninfect->2->3
#
# consequ->2->2
#
# wang->2->4
#
# higher->2->11
#
# autophagosom->2->1
#
# reveal->2->3
#
# calcium->2->3
#
# store->2->2 3->1
#
# signal->2->1
#
# stronger->2->2
#
# quantiti->2->1
#
# larg->2->4 4->1
#
# per->2->3
#
# strength->2->1
#
# fatal->2->4
#
# negat->2->7
#
# pathogen->2->12
#
# threat->2->3
#
# helicobact->2->1
#
# feli->2->1
#
# leishmania->2->2
#
# nippostrongylus->2->1
#
# brasiliensi->2->1
#
# transmit->2->6
#
# mouth->2->3
#
# oocyst->2->18
#
# accident->2->1
#
# eaten->2->2
#
# transmitt->2->1
#
# hematogen->2->2
#
# stem->2->2
#
# oral->2->1
#
# ingest->2->9
#
# raw->2->9
#
# meat->2->17
#
# especi->2->4
#
# pork->2->1
#
# lamb->2->2
#
# venison->2->1
# preval->2->11
#
# undercook->2->4
#
# contact->2->4 3->1
#
# handl->2->2
#
# knive->2->1
#
# utensil->2->1
#
# board->2->1 3->2
#
# contamin->2->3
#
# unwash->2->1
#
# fruit->2->1
#
# veget->2->1
#
# soil->2->3
#
# garden->2->3 4->2
#
# sandpit->2->1
#
# environ->2->4
#
# untreat->2->3
#
# unfilt->2->1
#
# consumpt->2->7
#
# util->2->2
#
# unpasteur->2->1
#
# milk->2->5
#
# product->2->3 3->4
#
# particular->2->6 3->1
#
# goat->2->6
#
# seafood->2->1
#
# excret->2->2
#
# contract->2->5
#
# intermedi->2->4
#
# shed->2->6
#
# undergo->2->2
#
# sporul->2->2
#
# potenti->2->6
#
# involv->2->3 3->1
#
# vari->2->10 4->2
#
# speci->2->6
#
# mode->2->1
#
# seroneg->2->5
#
# recipi->2->6
#
# seroposit->2->15
#
# donor->2->2
#
# reactiv->2->2
#
# immunosuppress->2->2
#
# striat->2->1
#
# make->2->4 3->1
#
# screen->2->5 3->3
#
# prior->2->4 4->1
#
# procedur->2->1
#
# specif->2->18
#
# unborn->2->2
#
# placenta->2->2
#
# fetal->2->5
#
# miscarriag->2->1
#
# hydrocephalus->2->3
#
# cerebr->2->3
#
# calcif->2->1
#
# encephalopathi->2->1
#
# blind->2->1
#
# titer->2->8
#
# previous->2->5
#
# ensur->2->1
#
# safeti->2->1
#
# draw->2->2
#
# prenat->2->4
#
# doctor->2->1
#
# determin->2->5 3->1
#
# educ->2->4 3->1 4->1
#
# parent->2->1 3->2
#
# improv->2->2
#
# pet->2->2
#
# hygien->2->3
#
# antenat->2->1
#
# dramat->2->2 3->1
#
# resili->2->1
#
# throughout->2->3 3->1
#
# difficult->2->4
#
# erad->2->1
#
# antiprotozoan->2->1
#
# serious->2->2
#
# despit->2->1
#
# routin->2->1
#
# reason->2->1
#
# cost->2->1 3->1
#
# fals->2->2
#
# generat->2->2
#
# portug->2->1
#
# franc->2->5 3->3
#
# austria->2->1
#
# uruguay->2->1
#
# itali->2->4
#
# except->2->2
#
# region->2->4 4->1
#
# programm->2->1
#
# oper->2->3
#
# germani->2->1 3->1
#
# switzerland->2->1
#
# belgium->2->1
#
# incur->2->1
#
# loss->2->4 3->1
#
# postnat->2->2
#
# neonat->2->5
#
# prefer->2->2
#
# abnorm->2->1
#
# note->2->6 3->2 4->1
#
# drink->2->1
#
# regardless->2->1
#
# relationship->2->5 3->2
#
# refrain->2->1
#
# buri->2->1 3->1
#
# shown->2->5 4->1
#
# household->2->1
#
# though->2->3 3->1
#
# kitten->2->1
#
# czech->2->2 3->1
#
# team->2->1
#
# discov->2->1
#
# boy->2->6 3->1
#
# girl->2->2 3->1
#
# chanc->2->7
#
# mri->2->1
#
# primari->2->4
#
# occipit->2->1
#
# lobe->2->1
#
# biolog->2->10
#
# histolog->2->2
#
# molecular->2->8
#
# combin->2->7
#
# lymphoma->2->1
#
# clinic->2->26
#
# suffici->2->2
#
# characterist->2->3
#
# altern->2->2
#
# support->2->2
#
# fail->2->2 3->2
#
# trial->2->1
#
# antimicrobi->2->2
#
# therapi->2->6
#
# pyrimethamin->2->6
#
# sulfadiazin->2->3
#
# usan->2->1
#
# leucovorin->2->2
#
# drug->2->14
#
# detect->2->15
#
# polymeras->2->3
#
# chain->2->2
#
# reaction->2->2
#
# inact->2->1
#
# evad->2->1
#
# serum->2->1
#
# sabin->2->6
#
# feldman->2->3
#
# dye->2->4
#
# dt->2->3
#
# indirect->2->2
#
# hemagglutin->2->1
#
# assay->2->11
#
# fluoresc->2->5
#
# ifa->2->3
#
# agglutin->2->6
#
# latex->2->1
#
# lat->2->1
#
# enzym->2->4
#
# immunosorb->2->3
#
# elisa->2->4
#
# iaat->2->1
#
# measur->2->9
#
# igg->2->20
#
# modifi->2->5
#
# peak->2->2
#
# bloodstream->2->1
#
# current->2->5
#
# extent->2->1
#
# differenti->2->2
#
# avid->2->3
#
# variat->2->3 3->1
#
# low->2->6
#
# affin->2->3
#
# antigen->2->2
#
# began->2->1
#
# status->2->2
#
# gestat->2->3
#
# contrast->2->3
#
# igm->2->10
#
# sooner->2->1
#
# disappear->2->1
#
# faster->2->1
#
# recoveri->2->2
#
# doubl->2->1
#
# sandwich->2->1
#
# isaga->2->1
#
# commerci->2->3
#
# kit->2->1
#
# misinterpret->2->1
#
# twenti->2->1
#
# evalu->2->3
#
# systemat->2->8
#
# comparison->2->2
#
# accept->2->1 3->1
#
# immunoassay->2->1
#
# immunochromatograph->2->1
#
# western->2->1 4->1
#
# blot->2->1
#
# sensit->2->3
#
# standard->2->2
#
# wb->2->1
#
# eia->2->1
#
# predict->2->2
#
# ppv->2->1
#
# discrimin->2->2
#
# wherea->2->3
#
# dispar->2->1
#
# npv->2->1
#
# key->2->2
#
# paramet->2->1
#
# assess->2->1
#
# patient->2->10
#
# ultrasound->2->1
#
# examin->2->5
#
# cord->2->2
#
# childhood->2->3
#
# ophthalmolog->2->1
#
# interv->2->1
#
# heavili->2->1
#
# reli->2->1
#
# immunoglobulin->2->2
#
# might->2->3
#
# undetect->2->2
#
# pcr->2->10
#
# techniqu->2->6
#
# diagnos->2->7
#
# specimen->2->1
#
# biopsi->2->1
#
# nest->2->1
#
# hybrid->2->3
#
# downsid->2->1
#
# quantit->2->2
#
# real->2->2
#
# gene->2->8 3->1
#
# regul->2->6
#
# allel->2->1
#
# nucleas->2->2
#
# taq->2->1
#
# cleav->2->1
#
# nonextend->2->1
#
# label->2->1
#
# probe->2->3
#
# carboxi->2->1
#
# tetramethyl->2->1
#
# rhodamin->2->1
#
# quench->2->2
#
# intact->2->1
#
# cleavag->2->1
#
# proport->2->1
#
# amount->2->2
#
# monitor->2->1
#
# sequenc->2->1
#
# detector->2->1
#
# immunostain->2->1
#
# demarc->2->1
#
# germin->2->2
#
# cluster->2->1
#
# monocytoid->2->2
#
# scatter->2->2
#
# epithelioid->2->2
#
# histiocyt->2->2
#
# classic->2->2 3->1
#
# triad->2->1
#
# intracrani->2->2
#
# arteriosclerosi->2->1
#
# sensorineur->2->3
#
# deaf->2->1
#
# intellectu->2->1
#
# disabl->2->2
#
# impact->2->4 3->1
#
# degre->2->2
#
# communic->2->1
#
# publish->2->1 3->4
#
# look->2->2 3->2
#
# whom->2->1 3->1
#
# languag->2->2 3->1 4->2
#
# hiv->2->6
#
# whose->2->1
#
# cd->2->3
#
# count->2->2
#
# cellsmm->2->1
#
# trimethoprimsulfamethoxazol->2->1
#
# choic->2->2
#
# promis->2->1
#
# endochin->2->2
#
# quinolon->2->2
#
# prescrib->2->2
#
# antimalari->2->1
#
# folic->2->2
#
# supplement->2->1
#
# incid->2->3
#
# thrombocytopaenia->2->2
#
# clindamycin->2->4
#
# minocyclin->2->1
#
# salvag->2->1
#
# trimest->2->5
#
# late->2->1 3->2
#
# reach->2->2 4->1
#
# concentr->2->1
#
# atovaquon->2->3
#
# seem->2->2
#
# optim->2->1
#
# mice->2->13
#
# amniocentesi->2->1
#
# help->2->6 3->1
#
# antifol->2->1
#
# interfer->2->1
#
# earlier->2->1 3->1
#
# correl->2->9
#
# poorer->2->1
#
# outcom->2->4
#
# mileston->2->1
#
# creat->2->2
#
# childbear->2->2
#
# latin->2->1
#
# america->2->7 3->5
#
# europ->2->3 3->2
#
# middl->2->2 3->4
#
# africa->2->2 3->1
#
# nutrit->2->4
#
# nhane->2->2
#
# us->2->7
#
# down->2->2
#
# foreign->2->1
#
# trend->2->7
#
# seropreval->2->18
#
# european->2->5 4->1
#
# consid->2->7
#
# foodborn->2->4
#
# fourth->2->1
#
# hospit->2->4
#
# protist->2->1
#
# ii->2->4 3->5
#
# iii->2->3 4->2
#
# lesser->2->1
#
# serotyp->2->1
#
# pose->2->2
#
# guarante->2->2
#
# necessarili->2->1
#
# tunisia->2->1
#
# splendor->2->3
#
# brazil->2->1
#
# protozoan->2->5
#
# rabbit->2->2
#
# african->2->1
#
# gundi->2->2
#
# ctenodactylus->2->1
#
# curv->2->1
#
# root->2->1
#
# toxon->2->1
#
# janku->2->2
#
# autopsi->2->1
#
# mark->2->3 3->4 4->1
#
# choroid->2->1
#
# sporocyt->2->1
#
# analysi->2->7
#
# analyz->2->2
#
# virus->2->1
#
# olitski->2->3
#
# laboratori->2->4
#
# monkey->2->1
#
# oblig->2->1
#
# fed->2->1 4->1
#
# demonstr->2->3
#
# york->2->6 3->21
#
# wolf->2->3 3->1
#
# cowen->2->3
#
# paig->2->2
#
# deliv->2->1
#
# caesarean->2->1
#
# section->2->2 3->1
#
# encephalomyel->2->1
#
# die->2->6 3->6
#
# isol->2->7
#
# inject->2->1
#
# spinal->2->1
#
# sampl->2->2
#
# rat->2->8
#
# conclud->2->1
#
# recogniz->2->1
#
# pinkerton->2->1
#
# weinman->2->1
#
# peru->2->1
#
# subsequ->2->2
#
# bacteri->2->1
#
# gold->2->1 3->1
#
# desmont->2->3
#
# pari->2->1 3->2
#
# therapeut->2->2
#
# beef->2->2
#
# couvreur->2->1
#
# harm->2->2
#
# gain->2->1
#
# attent->2->1
#
# suppress->2->2
#
# bone->2->1
#
# marrow->2->1
#
# epidem->2->1
#
# suscept->2->5
#
# syndrom->2->2
#
# coin->2->1
#
# news->2->3 3->2
#
# suspect->2->1 3->1
#
# ownership->2->4 4->1
#
# schizophrenia->2->25
#
# further->2->2 3->2
#
# causat->2->1
#
# psychos->2->1
#
# stereotyp->2->2
#
# popular->2->1
#
# instanc->2->2
#
# aforement->2->1
#
# afflict->2->1
#
# amongst->2->1
#
# populac->2->1
#
# compuls->2->1
#
# hoard->2->1
#
# dote->2->1
#
# biologist->2->1
#
# jaroslav->2->3
#
# flegr->2->8
#
# propon->2->1
#
# theori->2->1
#
# tenni->2->3
#
# player->2->2
#
# arthur->2->2 3->36
#
# ash->2->3 3->1
#
# actor->2->1 3->1
#
# merritt->2->2
#
# butrick->2->2
#
# alreadi->2->2
#
# pedro->2->2
#
# zamora->2->2
#
# realiti->2->1
#
# televis->2->1
#
# activist->2->1
#
# francoi->2->2
#
# clermont->2->1
#
# pretend->2->1
#
# throne->2->1
#
# overlook->2->1
#
# actress->2->1
#
# lesli->2->1 3->1
#
# distanc->2->2
#
# runner->2->1
#
# sebastian->2->1
#
# coe->2->3
#
# train->2->1 3->3 4->1
#
# martina->2->1
#
# navratilova->2->1
#
# virtual->2->2
#
# arrow->2->1
#
# macrophag->2->1
#
# capabl->2->2
#
# genera->2->1
#
# diet->2->2
#
# asian->2->1
#
# primat->2->1
#
# toqu->2->2
#
# macaqu->2->2
#
# macaca->2->2
#
# sinica->2->2
#
# endem->2->1
#
# island->2->1 3->1
#
# sri->2->2
#
# lanka->2->2
#
# australian->2->1
#
# marsupi->2->1
#
# wallabi->2->1
#
# koala->2->1
#
# wombat->2->1
#
# pademelon->2->1
#
# dasyurid->2->1
#
# bar->2->2 3->1
#
# bandicoot->2->1
#
# wild->2->6 3->1
#
# swine->2->2
#
# worldwid->2->4
#
# across->2->2
#
# globe->2->1 3->1
#
# lowest->2->1
#
# geograph->2->3
#
# warmer->2->1
#
# humid->2->1
#
# boar->2->3
#
# farm->2->3
#
# manag->2->3 3->1 4->1
#
# practic->2->1
#
# outdoor->2->2
#
# rais->2->3 3->1
#
# indoor->2->2
#
# confin->2->2
#
# percentag->2->1
#
# harbor->2->2
#
# viabl->2->5
#
# bioassay->2->2
#
# herd->2->1
#
# piglet->2->1
#
# progress->2->1
#
# stillbirth->2->1
#
# foundat->2->1 3->2 4->2
#
# thiptara->2->1
#
# stillborn->2->1
#
# thailand->2->1
#
# relev->2->1 3->1
#
# porcicultur->2->1
#
# intend->2->1
#
# backyard->2->1
#
# thorough->2->1
#
# poultri->2->1
#
# buffalo->2->2
#
# elimin->2->2
#
# slaughter->2->1
#
# export->2->1
#
# felin->2->5
#
# middletown->2->1
#
# ny->2->1 3->2
#
# investig->2->5
#
# exhibit->2->1
#
# offici->2->1 3->1
#
# purebr->2->1
#
# shelter->2->1
#
# finland->2->2
#
# overal->2->2
#
# feral->2->3
#
# giza->2->1
#
# egypt->2->2
#
# colombia->2->1
#
# chines->2->1
#
# guangdong->2->1
#
# just->2->1 4->2
#
# lifestyl->2->1
#
# hunt->2->1 3->1
#
# prey->2->2
#
# each->2->1
#
# vaccin->2->1
#
# challeng->2->2
#
# program->2->2
#
# avail->2->1
#
# question->2->1
#
# efficaci->2->4
#
# thought->2->2
#
# reduct->2->1
#
# innat->2->3
#
# avers->2->5
#
# odor->2->7
#
# urin->2->1
#
# moreov->2->1
#
# predat->2->5
#
# mink->2->1
#
# induc->2->15
#
# epigenet->2->12
#
# remodel->2->3
#
# neuron->2->7
#
# methyl->2->3
#
# hypomethyl->2->1
#
# arginin->2->1
#
# vasopressin->2->1
#
# medial->2->2
#
# amygdala->2->2
#
# great->2->1 4->1
#
# similar->2->2 4->1
#
# mous->2->3
#
# model->2->7
#
# addict->2->7
#
# histon->2->6
#
# knockout->2->1
#
# inhibit->2->6
#
# widespread->2->1
#
# lysin->2->2
#
# acetyl->2->5
#
# cortic->2->2
#
# astrocyt->2->2
#
# beyond->2->2
#
# neophob->2->1
#
# locomot->2->1
#
# exploratori->2->1
#
# experiment->2->9
#
# greater->2->2
#
# move->2->1
#
# acceler->2->1
#
# paus->2->1
#
# arena->2->2
#
# anxieti->2->2
#
# elev->2->1
#
# plus->2->3
#
# maze->2->5
#
# field->2->1 3->1
#
# social->2->2 3->2
#
# interact->2->3
#
# california->2->2
#
# davi->2->1
#
# dead->2->2 4->1
#
# sea->2->4
#
# otter->2->4
#
# collect->2->1
#
# proxim->2->1
#
# freshwat->2->1
#
# outflow->2->1
#
# ocean->2->3
#
# sourc->2->5
#
# runoff->2->1
#
# flush->2->1
#
# toilet->2->1
#
# introduc->2->1
#
# endang->2->5
#
# hawaiian->2->4
#
# monk->2->5
#
# seal->2->5
#
# contribut->2->2 3->1
#
# threaten->2->3
#
# pinnip->2->1
#
# dolphin->2->1
#
# whale->2->2
#
# massi->2->2
#
# believ->2->1 4->1
#
# anchovi->2->1
#
# estuari->2->1
#
# zoo->2->2
#
# china->2->1 3->1
#
# gastroenter->2->1
#
# respiratori->2->1
#
# anecdot->2->1
#
# emphas->2->1
#
# micrograph->2->1
#
# pale->2->1
#
# subt->2->1
#
# tendenc->2->2
#
# intens->2->1
#
# psychiatr->2->3
#
# trait->2->7
#
# conduct->2->1
#
# onset->2->3
#
# unclear->2->3
#
# share->2->1
#
# likelihood->2->1
#
# causal->2->2
#
# meta->2->6
#
# analys->2->1
#
# caution->2->1
#
# bias->2->1
#
# sex->2->2
#
# explain->2->2 3->2
#
# femal->2->2
#
# basi->2->1
#
# antipsychot->2->1
#
# suppos->2->1 4->1
#
# whi->2->3
#
# plausibl->2->1
#
# explan->2->1
#
# genet->2->3
#
# rout->2->1
#
# ocd->2->1
#
# suicid->2->1
#
# mood->2->2
#
# bipolar->2->2
#
# uncorrel->2->1
#
# depress->2->1
#
# dysthymia->2->1
#
# psycholog->2->2
#
# littl->2->1
#
# impuls->2->2
#
# aberr->2->1
#
# neurocognit->2->1
#
# impair->2->3
#
# parkinson->2->1
#
# alzheim->2->1
#
# sclerosi->2->2
#
# automobil->2->1
#
# psychomotor->2->1
#
# occurr->2->1
#
# distribut->2->4
#
# canadian->2->1
#
# arctic->2->1
#
# ...
#
# inhibitori->2->1
#
# postsynapt->2->1
#
# ipsc->2->2
#
# strike->2->1
#
# vanaga->2->1
#
# jeffer->2->2
#
# bogado->2->1
#
# ss->2->1
#
# dalmasso->2->1
#
# mc->2->1
#
# sullivan->2->2
#
# wj->2->2
#
# angel->2->1
#
# novel->2->1 3->1
#
# expert->2->1
#
# eri->2->1
#
# bouchut->2->1
#
# chawla->2->1
#
# hudmon->2->1
#
# proteom->2->1
#
# hl->2->1
#
# bristow->2->2
#
# gc->2->2
#
# jeb->2->3
#
# afonso->2->1
#
# paixao->2->1
#
# costa->2->1
#
# hakimi->2->1
#
# gonzalez->2->1
#
# rojnik->2->1
#
# urrea->2->1
#
# urdaneta->2->1
#
# petrosino->2->1
#
# colasant->2->1
#
# pino->2->1
#
# hernandez->2->1
#
# feb->2->1
#
# kreuder->2->1
#
# jame->2->1 3->6
#
# er->2->1
#
# mazet->2->1
#
# dabritz->2->1
#
# jessup->2->1
#
# gulland->2->1
#
# grigg->2->1
#
# sentinel->2->1
#
# talk->2->1
#
# friday->2->1
#
# radio->2->1 3->10
#
# noaa->2->1
#
# atmospher->2->1
#
# diep->2->1
#
# dawson->2->1
#
# teresa->2->1
#
# honnold->2->1
#
# sp->2->1
#
# braun->2->1
#
# scott->2->1 3->1
#
# dp->2->1
#
# sreekumar->2->1
#
# monachus->2->1
#
# schauinslandi->2->1
#
# quebec->2->1
#
# beluga->2->1
#
# cbc->2->1
#
# oct->2->1
#
# sidhartha->2->1
#
# banerje->2->1
#
# gloeta->2->1
#
# ware->2->1
#
# michael->2->2 3->11
#
# villega->2->2
#
# eric->2->1
#
# uptak->2->1
#
# migratori->2->1
#
# filter->2->1
#
# feed->2->1
#
# fish->2->1
#
# fuglewicz->2->1
#
# piotrowski->2->1
#
# stodolak->2->1
#
# acem->2->1
#
# kaushik->2->1
#
# understand->2->1
#
# physiolog->2->1
#
# morpholog->2->1
#
# pros->2->1
#
# con->2->1
#
# hypothesi->2->1
#
# bartko->2->1
#
# jj->2->1
#
# updat->2->1
#
# schbulsb->2->1
#
# aria->2->1
#
# sorlozano->2->1
#
# dio->2->1
#
# luna->2->1
#
# mckenney->2->1
#
# cervilla->2->1
#
# gutierrez->2->2
#
# agent->2->1
#
# schbulsbm->2->1
#
# barro->2->1
#
# jlvm->2->1
#
# barbosa->2->1
#
# ig->2->1
#
# salem->2->1
#
# rocha->2->1
#
# np->2->1
#
# kummer->2->1
#
# okusaga->2->1
#
# oo->2->1
#
# soar->2->1
#
# teixeira->2->1
#
# pearc->2->1
#
# bd->2->1
#
# psychiatri->2->1
#
# biopsych->2->1
#
# sugden->2->1
#
# moffitt->2->1
#
# terri->2->1 3->1
#
# pinto->2->1
#
# laurian->2->1
#
# poulton->2->1
#
# richi->2->1
#
# benjamin->2->1
#
# caspi->2->1
#
# avshalom->2->1
#
# tanowitz->2->1
#
# herbert->2->1 3->1
#
# stascheit->2->1
#
# rosch->2->1
#
# neuroimmunolog->2->1
#
# jneuroim->2->1
#
# shaban->2->1
#
# mehdi->2->1
#
# shahabeddin->2->1
#
# mahmood->2->1
#
# reza->2->1
#
# sey->2->1
#
# abdollah->2->1
#
# afsaneh->2->1
#
# abdolsattar->2->1
#
# ahmad->2->1
#
# yan->2->1
#
# chao->2->1
#
# liang->2->1
#
# jun->2->1
#
# zheng->2->1
#
# kui->2->1
#
# yang->2->1
#
# zhu->2->1
#
# xing->2->1
#
# dolgin->2->1
#
# eli->2->1
#
# ice->2->1
#
# melt->2->1
#
# domain->2->1
#
# factsheet->2->1
#
# academ->2->1
#
# boca->2->1
#
# raton->2->1
#
# crc->2->1
#
# xvii->2->1
#
# oclc->2->1 3->1
#
# speer->2->1
#
# sporozoit->2->1
#
# pozor->2->1
#
# toxo->2->1
#
# academia->2->1
#
# pragu->2->1
#
# republ->2->1 3->1
#
# merck->2->1
#
# agenc->2->1
#
# hpa->2->1
#
# video->2->1
#
# professor->2->1
#
# librari->2->2 3->5 4->1
#
# classificationdicd->2->1
#
# bicd->2->1
#
# mesh->2->1
#
# ddiseasesdb->2->1
#
# medlin->2->1
#
# med->2->1
#
# hide->2->1
#
# sar->2->1
#
# archaeplastidasaralveolateapicomplexaconoidasidacoccidia->2->1
#
# coccidia->2->1
#
# cryptosporidium->2->2
#
# homini->2->1
#
# parvum->2->1
#
# cryptosporidiosi->2->1
#
# cystoisospora->2->1
#
# belli->2->1
#
# isosporiasi->2->1
#
# cyclospora->2->1
#
# cayetanensi->2->1
#
# cyclosporiasi->2->1
#
# aconoidasida->2->1
#
# plasmodium->2->1
#
# falciparumvivaxovalemalariaeknowlesi->2->1
#
# malaria->2->1
#
# blackwat->2->1
#
# babesia->2->1
#
# babesiosi->2->1
#
# ciliophora->2->1
#
# balantidium->2->1
#
# coli->2->1
#
# balantidiasi->2->1
#
# heterokont->2->1
#
# blastocysti->2->1
#
# blastocystosi->2->1
#
# pythium->2->1
#
# insidiosum->2->1
#
# pythiosi->2->1
#
# archaeplastida->2->1
#
# algaemia->2->1
#
# prototheca->2->1
#
# wickerhamii->2->1
#
# protothecosi->2->1
#
# japan->2->1
#
# laurent->3->86
#
# playwright->3->24
#
# theatr->3->12
#
# director->3->20 4->1
#
# screenwrit->3->9
#
# laurentslaur->3->1
#
# bornarthur->3->1
#
# levin->3->3
#
# brooklyn->3->3
#
# diedmay->3->1
#
# rest->3->2
#
# placeund->3->1
#
# bench->3->2
#
# quogu->3->2
#
# occupationplaywrighttheatr->3->1
#
# directorfilm->3->1
#
# producerscreenwrit->3->1
#
# english->3->1
#
# alma->3->1
#
# mater->3->1
#
# cornel->3->3
#
# universityperiod->3->1
#
# award->3->33
#
# music->3->30
#
# hallelujah->3->6
#
# drama->3->5
#
# desk->3->3
#
# outstand->3->3
#
# gypsi->3->18
#
# writer->3->8
#
# guild->3->4
#
# screenplay->3->8
#
# cage->3->7
#
# aux->3->6
#
# follespartnertom->3->1
#
# hatcher->3->7
#
# film->3->21
#
# write->3->12
#
# script->3->13
#
# colleg->3->1 4->2
#
# broadway->3->17
#
# work->3->17
#
# own->3->2
#
# rope->3->7
#
# alfr->3->4
#
# hitchcock->3->5
#
# anastasia->3->4
#
# bonjour->3->3
#
# tristess->3->3
#
# theatric->3->2
#
# career->3->9
#
# blacklist->3->4
#
# memoir->3->6
#
# credit->3->5
#
# nomin->3->6
#
# honor->3->2
#
# read->3->2
#
# class->3->2
# jewish->3->6
#
# lawyer->3->1
#
# schoolteach->3->1
#
# gave->3->2
#
# marri->3->1
#
# flatbush->3->1
#
# borough->3->1
#
# attend->3->2
#
# erasmus->3->1
#
# hall->3->1 4->2
#
# sister->3->1
#
# edith->3->1
#
# chorea->3->1
#
# patern->3->1
#
# grandpar->3->1
#
# orthodox->3->1
#
# jew->3->1
#
# atheist->3->1
#
# kosher->3->1
#
# sake->3->1
#
# lax->3->1
#
# synagogu->3->1
#
# holiday->3->1
#
# mitzvah->3->1
#
# religi->3->1 4->1
#
# reject->3->1
#
# fundamentalist->3->1
#
# himself->3->2
#
# admit->3->1
#
# sound->3->1
#
# job->3->1
#
# graduat->3->2
#
# robson->3->1
#
# instructor->3->1
#
# cbs->3->2
#
# directorproduc->3->1
#
# submit->3->3
#
# comed->3->1
#
# fantasi->3->1
#
# clairvoy->3->1
#
# columbia->3->1
#
# workshop->3->1
#
# shirley->3->1
#
# booth->3->1
#
# led->3->1
#
# hire->3->3
#
# lux->3->1
#
# theater->3->2
#
# interrupt->3->1
#
# draft->3->1
#
# cleric->3->1
#
# saw->3->1
#
# instead->3->1
#
# assign->3->3
#
# studio->3->3
#
# astoria->3->1
#
# wrote->3->5
#
# cukor->3->2
#
# holden->3->1
#
# reassign->3->1
#
# harvey->3->2
#
# fierstein->3->1
#
# jerri->3->3
#
# herman->3->1
#
# creator->3->1
#
# foll->3->5
#
# clum->3->5
#
# alway->3->1
#
# mirror->3->1
#
# leftist->3->1
#
# gay->3->3
#
# duti->3->1
#
# excel->3->1
#
# apprenticeship->3->1
#
# bud->3->1
#
# fortun->3->1
#
# brave->3->4
#
# sale->3->1
#
# entre->3->1
#
# hollywood->3->5
#
# mix->3->1
#
# adapt->3->2
#
# soon->3->1
#
# discharg->3->1
#
# ballerina->3->1
#
# nora->3->7
#
# kay->3->3
#
# off->3->2
#
# tour->3->2
#
# fanci->3->1
#
# discont->3->1
#
# medium->3->1
#
# urg->3->1
#
# gabel->3->1
#
# consecut->3->1
#
# night->3->1
#
# wholesal->3->3
#
# unknown->3->1
#
# barbra->3->2
#
# streisand->3->2
#
# next->3->3
#
# project->3->4
#
# anyon->3->5
#
# whistl->3->5
#
# infam->3->1
#
# flop->3->1
#
# written->3->3
#
# lena->3->1
#
# horn->3->1
#
# uggam->3->1
#
# reviv->3->4
#
# patti->3->1
#
# lupon->3->1
#
# tackl->3->1
#
# bilingu->3->2
#
# spanish->3->2
#
# translat->3->2
#
# dialogu->3->1
#
# lyric->3->2
#
# manuel->3->1
#
# miranda->3->1
#
# convent->3->1
#
# imposs->3->1
#
# charact->3->3
#
# authent->3->1
#
# brantley->3->2
#
# ad->3->1
#
# mr->3->1
#
# exchang->3->1
#
# insol->3->1
#
# innoc->3->1
#
# bargain->3->1
#
# dividend->3->1
#
# saint->3->1 4->1
#
# assist->3->1
#
# dialog->3->1
#
# frustrat->3->1
#
# disappoint->3->1
#
# anatol->3->1
#
# litvak->3->1
#
# unhappi->3->1
#
# frank->3->3
#
# parto->3->3
#
# millen->3->1
#
# brand->3->3
#
# snake->3->3
#
# pit->3->3
#
# rewrit->3->1
#
# insist->3->1
#
# bulk->3->1
#
# shoot->3->1
#
# carbon->3->1
#
# copi->3->2 4->1
#
# actual->3->1
#
# bolster->3->1
#
# claim->3->1
#
# rewritten->3->1
#
# deni->3->1
#
# confess->3->1
#
# scene->3->1
#
# apolog->3->1
#
# decept->3->1
#
# learn->3->2
#
# inelig->3->1
#
# wga->3->1
#
# benefit->3->1
#
# accumul->3->1
#
# enough->3->1
#
# qualifi->3->1
#
# fox->3->2
#
# pleas->3->1
#
# stewart->3->2
#
# want->3->1
#
# patrick->3->2
#
# hamilton->3->1
#
# lover->3->1
#
# farley->3->2
#
# granger->3->4
#
# happi->3->1
#
# dilemma->3->1
#
# audienc->3->1
#
# awar->3->1
#
# homosexu->3->1
#
# blatant->3->1
#
# offic->3->2 4->1
#
# tab->3->1
#
# final->3->1
#
# discreet->3->1
#
# unsur->3->1
#
# ever->3->1
#
# realiz->3->1
#
# ask->3->1
#
# torn->3->1
#
# curtain->3->1
#
# topaz->3->1
#
# unenthus->3->1
#
# incorpor->3->1
#
# huac->3->1
#
# reunit->3->1
#
# inspir->3->2
#
# love->3->5
#
# ross->3->1
#
# casual->3->1
#
# remark->3->1
#
# russel->3->1
#
# crous->3->1
#
# washington->3->1
#
# un->3->2
#
# committe->3->1
#
# primarili->3->2
#
# mccarran->3->1
#
# prohibit->3->1
#
# subvers->3->2
#
# obtain->3->1
#
# passport->3->4
#
# immedi->3->1
#
# appli->3->1
#
# depart->3->2
#
# harold->3->14
#
# clurman->3->1
#
# stella->3->1
#
# adler->3->1
#
# abroad->3->1
#
# jerom->3->5
#
# robbin->3->5
#
# dancin->3->2
#
# ballet->3->2
#
# ran->3->1
#
# nanci->3->3
#
# lang->3->1
#
# lawrenc->3->2
#
# lee->3->1
#
# approach->3->2
#
# paramount->3->1
#
# version->3->1
#
# agre->3->1
#
# packag->3->1
#
# daili->3->3
#
# worker->3->1
#
# decid->3->1
#
# refus->3->1
#
# renew->3->2
#
# lengthi->3->2
#
# letter->3->1
#
# belief->3->1
#
# idiosyncrat->3->1
#
# member->3->1
#
# sail->3->1
#
# ile->3->1
#
# cabl->3->1
#
# metro->3->1
#
# goldwyn->3->1
#
# mayer->3->5
#
# discuss->3->2
#
# affair->3->1
#
# tom->3->5
#
# aspir->3->1
#
# gore->3->1
#
# vidal->3->1
#
# bever->3->1
#
# admir->3->1
#
# posthum->3->1
#
# manhattan->3->1
#
# dim->3->2
#
# minut->3->1
#
# alongsid->3->1
#
# waltz->3->2
#
# madwoman->3->5
#
# park->3->5 4->1
#
# harper->3->1
#
# row->3->2
#
# cuckoo->3->2
#
# wood->3->2
#
# invit->3->3
#
# aaa->3->5
#
# dd->3->1
#
# edward->3->1
#
# lucasta->3->1
#
# jolson->3->1
#
# sing->3->1
#
# enclav->3->1
#
# radic->3->1
#
# mystiqu->3->1
#
# big->3->1 4->1
#
# potato->3->1
#
# claudia->3->1
#
# lazlo->3->1
#
# eve->3->1
#
# wherev->3->1
#
# laurentshatch->3->2
#
# annual->3->1 4->1
#
# grant->3->1
#
# nonprofit->3->1
#
# nomine->3->9
#
# winner->3->5
#
# edgar->3->1
#
# allan->3->1
#
# poe->3->1
#
# motion->3->1
#
# golden->3->1
#
# portalbox->3->7
#
# max->3->2
#
# bold->3->4
#
# portal->3->5
#
# novelist->3->1
#
# victim->3->1
#
# legendari->3->1
#
# betray->3->4
#
# amherst->3->2
#
# cambria->3->3
#
# obituari->3->3
#
# telegraph->3->1
#
# shark->3->2
#
# hawtre->3->1
#
# christoph->3->4
#
# hutchinson->3->1
#
# bill->3->2
#
# behind->3->1
#
# arnold->3->1
#
# bloomberg->3->1
#
# hal->3->1
#
# leonard->3->2
#
# knopf->3->3
#
# kenneth->3->3
#
# playbil->3->3
#
# our->3->1
#
# gang->3->1
#
# berson->3->1
#
# seattl->3->1
#
# forum->3->1
#
# vaill->3->1
#
# amanda->3->1
#
# somewher->3->2
#
# random->3->1
#
# inc->3->1
#
# internet->3->3
#
# backstag->3->1
#
# berkvist->3->1
#
# gan->3->1
#
# andrew->3->2
#
# partner->3->1
#
# sidebar->3->28
#
# fffa->3->1
#
# caption->3->2
#
# pretitl->3->4
#
# head->3->1
#
# mediawiki->3->1
#
# locationmus->3->1
#
# congresssourcearthur->3->1
#
# paper->3->1
#
# circa->3->1
#
# imdb->3->1
#
# wing->3->1
#
# worldcat->3->2
#
# catalog->3->1
#
# laurentswritermus->3->1
#
# paradis->3->1
#
# bennett->3->3
#
# charnin->3->1
#
# peter->3->3
#
# masterson->3->1
#
# tommi->3->6
#
# wilford->3->4
#
# leach->3->4
#
# abbott->3->3
#
# lapin->3->2
#
# mike->3->3
#
# ockrent->3->1
#
# elli->3->1
#
# zak->3->2
#
# des->3->3
#
# mcanuff->3->3
#
# nichola->3->2
#
# hytner->3->2
#
# renshaw->3->1
#
# walter->3->2
#
# bobbi->3->3
#
# taymor->3->2
#
# matthew->3->2
#
# bourn->3->2
#
# blakemor->3->2
#
# susan->3->2
#
# stroman->3->2
#
# jack->3->3
#
# obrien->3->2
#
# joe->3->2
#
# mantello->3->2
#
# doyl->3->3
#
# bartlett->3->3
#
# stephen->3->4
#
# daldri->3->2
#
# casey->3->2
#
# nicholaw->3->2
#
# trey->3->2
#
# tiffani->3->2
#
# dian->3->2
#
# paulus->3->2
#
# darko->3->2
#
# tresnjak->3->2
#
# kail->3->2
#
# rachel->3->3
#
# chavkin->3->3
#
# cromer->3->2
#
# tina->3->1
#
# landau->3->1
#
# brackett->3->1
#
# gower->3->3
#
# champion->3->3
#
# abe->3->1
#
# albert->3->1
#
# marr->3->1
#
# ron->3->2
#
# bob->3->1
#
# foss->3->1
#
# geoffrey->3->1
#
# holder->3->1
#
# sak->3->1
#
# maltbi->3->1
#
# jr->3->1
#
# trevor->3->3
#
# nunn->3->2
#
# caird->3->1
#
# rando->3->1
#
# nichol->3->1
#
# johnson->3->1
#
# sam->3->1
#
# ashley->3->1
#
# alex->3->1
#
# timber->3->1
#
# screenplayorigin->3->1
#
# goldman->3->2
#
# ford->3->1
#
# coppola->3->2
#
# edmund->3->1
#
# penelop->3->1
#
# gilliatt->3->1
#
# jeremi->3->1
#
# larner->3->1
#
# steve->3->3
#
# shagan->3->1
#
# town->3->2 4->1
#
# pierson->3->1
#
# paddi->3->2
#
# chayefski->3->2
#
# dowd->3->1
#
# waldo->3->1
#
# salt->3->1
#
# bridg->3->1
#
# bo->3->2
#
# beatti->3->2
#
# melissa->3->1
#
# mathison->3->1
#
# horton->3->1
#
# foot->3->1
#
# comedi->3->1
#
# mazurski->3->1
#
# larri->3->3
#
# neil->3->2
#
# bogdanovich->3->1
#
# buck->3->1
#
# newman->3->1
#
# benton->3->1
#
# melvin->3->1
#
# rose->3->2
#
# mel->3->1
#
# brook->3->2
#
# norman->3->2
#
# steinberg->3->1
#
# bergman->3->1
#
# pryor->3->1
#
# alan->3->2
#
# uger->3->1
#
# lancast->3->1
#
# woodi->3->5
#
# marshal->3->1
#
# brickman->3->1
#
# gelbart->3->2
#
# sheldon->3->1
#
# keller->3->1
#
# tesich->3->1
#
# meyer->3->1
#
# shyer->3->1
#
# gordon->3->1
#
# don->3->1
#
# mcguir->3->1
#
# murray->3->1
#
# schisgal->3->1
#
# kasdan->3->1
#
# benedek->3->1
#
# kelley->3->1
#
# earl->3->2
#
# wallac->3->2
#
# shanley->3->1
#
# shelton->3->1
#
# barri->3->2
#
# levinson->3->1
#
# calli->3->1
#
# khouri->3->1
#
# jordan->3->2
#
# campion->3->1
#
# joel->3->1
#
# coen->3->2
#
# ethan->3->1
#
# andrus->3->1
#
# stoppard->3->1
#
# ball->3->1
#
# lonergan->3->1
#
# julian->3->1
#
# fellow->3->1
#
# moor->3->1
#
# sofia->3->1
#
# charli->3->1
#
# kaufman->3->1
#
# haggi->3->1
#
# moresco->3->1
#
# arndt->3->1
#
# diablo->3->1
#
# codi->3->1
#
# dustin->3->1
#
# lanc->3->1
#
# boal->3->2
#
# nolan->3->1
#
# spike->3->1
#
# jonz->3->1
#
# wes->3->1
#
# anderson->3->1
#
# hugo->3->1
#
# guin->3->1
#
# mccarthi->3->1
#
# josh->3->2
#
# singer->3->1
#
# jenkin->3->1
#
# tarel->3->1
#
# alvin->3->1
#
# mccraney->3->1
#
# peel->3->1
#
# burnham->3->1
#
# bong->3->1
#
# joon->3->1
#
# ho->3->1
#
# han->3->1
#
# jin->3->1
#
# won->3->1
#
# emerald->3->1
#
# fennel->3->1
#
# bernstein->3->3
#
# sondheim->3->1
#
# shakespear->3->1
#
# romeo->3->1
#
# juliet->3->1
#
# suit->3->1
#
# swango->3->1
#
# bank->3->1
#
# parodi->3->1
#
# songsact->3->1
#
# someth->3->1
#
# maria->3->1
#
# tonight->3->2
#
# cool->3->1
#
# quintet->3->1
#
# chorus->3->1
#
# feel->3->1
#
# pretti->3->1
#
# gee->3->1
#
# krupk->3->1
#
# album->3->1
#
# cast->3->1
#
# previn->3->1
#
# soundtrack->3->2
#
# tjader->3->1
#
# brubeck->3->2
#
# quartet->3->2
#
# peterson->3->1
#
# trio->3->1
#
# kenton->3->2
#
# toshiko->3->1
#
# mariano->3->1
#
# akiyoshi->3->1
#
# hine->3->1
#
# superjail->3->1
#
# borinquena->3->1
#
# integr->3->1
#
# file->3->1
#
# isni->3->1
#
# viaf->3->1
#
# spain->3->1
#
# korea->3->1
#
# netherland->3->1
#
# poland->3->1
#
# facet->3->1
#
# applic->3->1
#
# terminolog->3->1
#
# musicbrainz->3->1
#
# context->3->1
#
# sudoc->3->1
#
# vizianagaram->4->19
#
# indiaaltern->4->1
#
# pusapati->4->1
#
# vizianagram->4->2
#
# district->4->2
#
# andhra->4->8
#
# indiacoordin->4->1
#
# typefortificationlength->4->1
#
# historyfoundedabandonedoccupiedsit->4->1
#
# northeastern->4->1
#
# vijaya->4->5
#
# raju->4->6
#
# formal->4->1
#
# lay->4->2
#
# victori->4->7
#
# entri->4->4
#
# nagar->4->4
#
# khana->4->9
#
# elabor->4->1
#
# moti->4->4
#
# oudh->4->5
#
# alakananda->4->4
#
# korukonda->4->4
#
# ganta->4->4
#
# stambham->4->5
#
# situat->4->1
#
# telugu->4->3
#
# bay->4->1
#
# bengal->4->1
#
# northwest->4->1
#
# visakhapatnam->4->1
#
# founder->4->2
#
# vijay->4->1
#
# ram->4->1
#
# ananda->4->1
#
# mahabub->4->1
#
# valli->4->1
#
# penanc->4->1
#
# forest->4->1
#
# chosen->4->1
#
# calendar->4->1
#
# tenth->4->1
#
# dasami->4->1
#
# dassara->4->1
#
# tuesday->4->1
#
# jayavaram->4->1
#
# corner->4->1
#
# fortif->4->1
#
# slope->4->1
#
# earth->4->1
#
# fill->4->1
#
# strengthen->4->1
#
# slab->4->1
#
# eleg->4->3
#
# stood->4->1
#
# smaller->4->1
#
# moat->4->2
#
# surround->4->1
#
# apart->4->1
#
# hanuman->4->1
#
# lakshmi->4->2
#
# kota->4->1
#
# shakto->4->1
#
# deiti->4->2
#
# prayer->4->1
#
# ghanta->4->1
#
# clock->4->3
#
# moddukovillu->4->1
#
# perla->4->3
#
# rajasthani->4->2
#
# drum->4->2
#
# beat->4->1
#
# arriv->4->1
#
# guest->4->3
#
# rear->4->1
#
# gateway->4->2
#
# tomb->4->1
#
# cremat->4->1
#
# extend->4->1
#
# court->4->1
#
# durbar->4->1
#
# vijayarama->4->1
#
# marbl->4->1
#
# glori->4->2
#
# donat->4->1
#
# maharajah->4->2
#
# alak->4->2
#
# narayan->4->1
#
# mansa->4->2
#
# trust->4->2
#
# dr->4->1
#
# saheb->4->1
#
# floor->4->1
#
# artifact->4->2
#
# stairway->4->2
#
# bathroom->4->2
#
# phool->4->2
#
# uniqu->4->1
#
# octagon->4->2
#
# adjoin->4->1
#
# spiral->4->1
#
# pump->4->1
#
# alaknanda->4->1
#
# plush->4->1
#
# laid->4->1
#
# walkway->4->1
#
# airstrip->4->1
#
# royalti->4->1
#
# battalion->4->1
#
# reserv->4->1
#
# polic->4->1
#
# nearer->4->1
#
# land->4->2
#
# acr->4->1
#
# ha->4->1
#
# playground->4->1
#
# tend->4->1
#
# institut->4->1
#
# youth->4->1
#
# wish->4->1
#
# join->4->1
#
# cream->4->1
#
# pydith->4->1
#
# ammavaru->4->1
#
# rever->4->1
#
# reincarn->4->1
#
# vijayadashami->4->1
#
# celebr->4->1
#
# jatra->4->1
#
# exemplifi->4->1
#
# union->4->1
#
# parvati->4->1
#
# electr->4->1
#
# bedroom->4->1
#
# fit->4->1
#
# bedstead->4->1
#
# silver->4->1
#
# furnitur->4->1
#
# chandeli->4->1
#
# kendriya->4->1
#
# vidyalaya->4->1
#
# voziangaram->4->1
#
# print->4->1
#
# stationeri->4->1
#
# secretariat->4->1
#
# bureau->4->1
#
# informat->4->1
#
# vijayanagaram->4->1
#
# registrar->4->1
#
# census->4->1
#
# narayana->4->1
#
# pharmaci->4->1
#
# bobbili->4->1
#
# chennamp->4->1
#
# gandikota->4->1
#
# gooti->4->1
#
# gurramkonda->4->1
#
# kondap->4->1
#
# kondaveedu->4->1
#
# konda->4->1
#
# reddi->4->1
#
# buruju->4->1

# %% [markdown]
# ### Query preprocessing

# %% [markdown]
# Steps followed
# 1. Tokenize the query
# 2. Convert infix query expression to postfix query expression using stack approach
#         a. Check if the given expression is balanced or not
#         b. Check is there any extra parenthesis in the expression
# 3. Processing two operator only in the query **\&**(and) , **\|** (or) and **\~**(negation) and giving higeher precedence to the former
# 4. Using **snowball_stemmer** as a stemmer algorithm to find the stem word in the given query
# 5. Generate binary vector based on document size and consider negation sign as well while processing
# 6. Find document which contains the query word using **find_matched_doc** function and return a binary vector that shows which document contains that word
# 7. Remove stop words from query

# %%
def is_operator(token):
    if token in ['&' , '|']:
        return True
    return False

#Precedence of operators
def precedence_oper(token):
    if token=='&': return 2
    elif token=='|': return 1
    else: return -1

def get_postfix_list(tokens):
    stack = []
    postfix_list = []
    for token in tokens:
        #If token is left small bracket '('
        if token == '(': stack.append(token)
        elif token == ')':
            while(len(stack)>0 and stack[-1]!='('):
                postfix_list.append(stack.pop())
            if len(stack)==0 and token==')':
                raise ValueError('Either unnecessary parenthesis or Not a balanced query')
            stack.pop()
            if len(stack)>0 and stack[-1] == '(':
                raise ValueError('Either unnecessary parenthesis or Not a balanced query')
        elif is_operator(token):
            while(len(stack)>0 and precedence_oper(token) <= precedence_oper(stack[-1])):
                postfix_list.append(stack.pop())
            stack.append(token)
        else: 
            postfix_list.append(token)
    while len(stack)>0:
        postfix_list.append(stack.pop())
    return postfix_list

# %%
def query_preprocessing(q):
    #Remove stop words from query
    stop_words = set(stopwords.words('english'))
    #Tokenize query first
    q_tokens = word_tokenize(q)
    new_q_tokens = [word for word in q_tokens if word not in stop_words]
    #Convert this infix list into postfix list to process operator in right way
    q_tokens = get_postfix_list(new_q_tokens)
    return q_tokens

# %%
def get_stemmer(stemmer_type):
    if(stemmer_type=='porter_stemmer'): stemmer = nltk.PorterStemmer()
    elif(stemmer_type=='snowball_stemmer'): stemmer = nltk.SnowballStemmer(language = 'english')
    return stemmer

# %%
def get_binary_vec(token, postings_list, doc_size):
    word_embedd = np.zeros(doc_size, dtype=int)
    vocab = postings_list.keys()
    negation = False
    if token[0]=='~':
        negation=True
        token=token[1:]
    if token not in vocab:
        print(token + " was not found in the corpus")
        return word_embedd
    node = postings_list[token]
    while node is not None:
        word_embedd[node.docID] = 1
        node=node.next
    if negation:
        word_embedd = np.invert(word_embedd)
    return word_embedd

# %%
def find_matched_doc(query_tokens, postings_list, doc_index, top_k):
    
    word_embedd_stack = []
    doc_size = len(doc_index)
    
    for token in query_tokens:
        if is_operator(token):
            if(len(word_embedd_stack)<2): 
                raise ValueError("Query is not correct or use more stopping words")
            first_operand = word_embedd_stack.pop()
            second_operand = word_embedd_stack.pop()
            
            if token=='&': word_embedd_stack.append(first_operand & second_operand)
            elif token=='|': word_embedd_stack.append(first_operand | second_operand)
            else:
                raise ValueError('Can\'t process this operator: ', token)
        else:
            stemmer = get_stemmer('snowball_stemmer')
            st = stemmer.stem(token)
            
            token_embedd = get_binary_vec(token, postings_list, doc_size)
            word_embedd_stack.append(token_embedd)
    matched_doc = [doc_index[docID] for docID in np.where(word_embedd_stack[-1])[0]]
    return matched_doc[:top_k]

# %%
queries_list = ['person | technology', 'man | indiashow']
top_k=3
print("Top {} documents retrieved".format(top_k))
for query in queries_list:
    query_tokens = query_preprocessing(query)
    matched_doc = find_matched_doc(query_tokens, postings_list, doc_index, top_k)
    print(matched_doc)
# Out:
# Top 3 documents retrieved
# technology was not found in the corpus
# ['P_386', 'D00585']
# ['T00921', 'D00585']

# %%
vocab_doc_wise_stemming.keys()
# Out:
# dict_keys(['P_386', 'T00921', 'D00585', 'L00119', 'T00755'])

# %%
list(postings_list.keys()).index('return')
# Out:
# 11

# %% [markdown]
# ## Tf-Idf Retrieval System

# %%
def get_doc_tf(doc, query_tokens, postings_list, doc_doc_index):
    doc_vector = np.zeros(len(postings_list.keys()), dtype=int)
    for token in doc:
        if token not in postings_list.keys():
            print(token + ' was not found in corpus')
        elif token not in query_tokens:
            continue
        else:
            node = postings_list[token]
            while node is not None:
                if node.docID == doc_doc_index: break
                node=node.next
            idx = list(postings_list.keys()).index(token)
            doc_vector[idx]=node.freq
    return doc_vector

def get_doc_idf(doc, query_tokens, postings_list, doc_size):
    inverse_freq={}
    for token in doc:
        if (token not in postings_list.keys()) or (token not in query_tokens):
            inverse_freq[token]=0
        else:
            node = postings_list[token]
            dft=0
            while node is not None:
                dft+=1
                node=node.next
            inverse_freq[token] = math.log(doc_size / dft)
    return inverse_freq

def get_doc_tf_idf(doc_vector, postings_list, inv_doc_freq):
    for token, token_freq in inv_doc_freq.items():
        idx = list(postings_list.keys()).index(token)
        doc_vector[idx] = doc_vector[idx]*token_freq
    doc_len = np.linalg.norm(doc_vector)
    doc_vector = doc_vector/doc_len
    return doc_vector

def get_query_vector(query_tokens, postings_list):
    query_vector = np.zeros(len(postings_list.keys()), dtype=int)
    for token in query_tokens:
        if token not in postings_list.keys():
            print(token + ' was not found in corpus')
        else:
            idx = list(postings_list.keys()).index(token)
            query_vector[idx] += 1
    return query_vector

def get_scoring_vec(tf_idf_matrix, doc_size):
    score_vector = np.zeros(doc_size, dtype=float)
    for _, vec in tf_idf_matrix.items():
        score_vector += vec
    return score_vector

def get_mapped_doc(score_vec, doc_index, top_k):
    doc_idx_mapping = np.arange(len(doc_index))
    get_matched_doc = [doc_index[docID] for score, docID in sorted(zip(score_vec, doc_idx_mapping), reverse=True)]
    return get_matched_doc[:top_k]

# %%
def get_docs_tf_idf_vector(query_tokens, vocab_doc_wise_stemming, postings_list, doc_index):
    doc_tf_idf_vector={}
    for doc, doc_vocab in vocab_doc_wise_stemming.items():
#         print(doc)
        idx = list(doc_index.values()).index(doc)
        doc_vector = get_doc_tf(doc_vocab, query_tokens, postings_list, idx)
    #     print("Doc vector: ", len(doc_vector))
        doc_inv_term_freq = get_doc_idf(doc_vocab, query_tokens, postings_list, len(doc_index))
    #     print("Doc inv freq: ", doc_inv_term_freq)
        doc_tf_idf = get_doc_tf_idf(doc_vector,postings_list, doc_inv_term_freq)
        doc_tf_idf_vector[doc] = doc_tf_idf
    #     print("doc_tf_idf: ", len(doc_tf_idf))
    return doc_tf_idf_vector

# %%
queries_list = ['person and technology and brahmana but not movie', 'man or indiashow']
top_k=3
print("Top {} documents retrieved".format(top_k))
for query in queries_list:
    #Tokenize query first
    q_tokens = word_tokenize(query)
    #Remove stop words from query
    stop_words = set(stopwords.words('english'))
    new_q_tokens = [word for word in q_tokens if word not in stop_words]
    V_q = get_query_vector(new_q_tokens, postings_list)
#     print(new_q_tokens)
#     print(V_q)
    q_sim_score=[]
    q_sim_score_map_doc_name=[]
    doc_tf_idf_vector = get_docs_tf_idf_vector(new_q_tokens, vocab_doc_wise_stemming, postings_list, doc_index)
    for doc, v_d in doc_tf_idf_vector.items():
        cos_sim = np.dot(V_q, v_d)/(np.linalg.norm(V_q) * np.linalg.norm(v_d))
        q_sim_score.append(cos_sim)
        q_sim_score_map_doc_name.append(doc)
        print(cos_sim)
    print(q_sim_score_map_doc_name)
    sim_score = [docName for score, docName in sorted(zip(q_sim_score, q_sim_score_map_doc_name), reverse=True)]
    print(sim_score[:top_k])
# Out:
# Top 3 documents retrieved
# technology was not found in corpus
# movie was not found in corpus
# /home/rahul/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# 0.7071067811865475
# nan
# 0.7071067811865475
# nan
# nan
# ['P_386', 'T00921', 'D00585', 'L00119', 'T00755']
# ['P_386', 'T00921', 'D00585']
# nan
# 0.7556890827898176
# nan
# nan
# nan
# ['P_386', 'T00921', 'D00585', 'L00119', 'T00755']
# ['P_386', 'T00921', 'D00585']

# %%
len(doc_index)
# Out:
# 5
